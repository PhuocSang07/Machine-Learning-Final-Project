# %% [markdown]
# # Báo cáo cuối kì Machine Learning
#
# ### Các thành viên trong nhóm:
# 1. Nguyễn Thái Khôi - MSSV: 52100637
# 2. Lê Khắc Thanh Tùng - MSSV: 52100943
# 3. Trần Phước Sang - MSSV: 52100303

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("airline_passenger_satisfaction.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %% [markdown]
# # Information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                          object
# dtype: object

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count           103904.000000  103904.000000   103904.000000    103904.000000
# mean                 2.756901       2.976883        3.202129         3.250375
# std                  1.398929       1.277621        1.329533         1.349509
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         Seat comfort  Inflight entertainment  On-board service  \
# count  103904.000000           103904.000000     103904.000000
# mean        3.439396                3.358158          3.382363
# std         1.319088                1.332991          1.288354
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     103904.000000     103904.000000    103904.000000     103904.000000
# mean           3.351055          3.631833         3.304290          3.640428
# std            1.315605          1.180903         1.265396          1.175663
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count  103904.000000               103904.000000             103594.000000
# mean        3.286351                   14.815618                 15.178678
# std         1.312273                   38.230901                 38.698682
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000

# %%
df.describe(exclude = np.number)
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count   103904          103904           103904    103904
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     52727           84923            71655     49665
#
#                    satisfaction
# count                    103904
# unique                        2
# top     neutral or dissatisfied
# freq                      58879

# %% [markdown]
# # Visualizing missing data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
del df["id"]
del df["Unnamed: 0"]

# %% [markdown]
# # Visualizing data

# %%
arr = [0, 1, 2, 3, 4, 5]

a = df["Gate location"].value_counts()[arr]

# %%
fig, ax = plt.subplots(12, 2)
plt.subplots_adjust(bottom=3, right=3, top=10)

ax[0, 0].pie(df["Gender"].value_counts(), labels=["Female", "Male"], colors=["#4a69bd", "#e58e26"], autopct='%1.0f%%')
ax[0, 0].title.set_text("Gender")

ax[0, 1].pie(df["Customer Type"].value_counts(), labels=["Loyel Customer", "Disloyal Customer"], colors=["#4a69bd", "#e58e26"], autopct='%1.0f%%')
ax[0, 1].title.set_text("Customer Type")

age_satis = df.loc[df["satisfaction"] == "satisfied"]["Age"]
age_dissatis = df.loc[df["satisfaction"] == "neutral or dissatisfied"]["Age"]
ax[1, 0].hist([age_satis, age_dissatis], bins=30, color=["#4a69bd", "#e58e26"], label=["satisfied", "neutral or dissatisfied"])
ax[1, 0].legend(loc='upper right')
ax[1, 0].title.set_text("Age")

ax[1, 1].pie(df["Type of Travel"].value_counts(), labels=["Bussiness Travel", "Personal Travel"], colors=["#4a69bd", "#e58e26"], autopct='%1.0f%%')
ax[1, 1].title.set_text("Type of Travel")

ax[2, 0].pie(df["Class"].value_counts(), labels=["Business", "Eco", "Eco Plus"], colors=["#4a69bd", "#e58e26", "#f8c291"], autopct='%1.0f%%')
ax[2, 0].title.set_text("Class")

flight_dis_satis = df.loc[df["satisfaction"] == "satisfied"]["Flight Distance"]
flight_dis_dissatis = df.loc[df["satisfaction"] == "neutral or dissatisfied"]["Flight Distance"]
ax[2, 1].hist([flight_dis_satis, flight_dis_dissatis], bins=20, color=["#4a69bd", "#e58e26"], label=["satisfied", "neutral or dissatisfied"])
ax[2, 1].title.set_text("Flight Distance")

x_ = np.sort(df["Inflight wifi service"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Inflight wifi service"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Inflight wifi service"])
    y_sa.append(df.loc[(df["Inflight wifi service"] == k) & (df["satisfaction"] == "satisfied")].count()["Inflight wifi service"])  
ax[3, 0].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[3, 0].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[3, 0].legend()
ax[3, 0].title.set_text("Inflight Wifi Service")

x_ = np.sort(df["Departure/Arrival time convenient"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Departure/Arrival time convenient"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Departure/Arrival time convenient"])
    y_sa.append(df.loc[(df["Departure/Arrival time convenient"] == k) & (df["satisfaction"] == "satisfied")].count()["Departure/Arrival time convenient"])  
ax[3, 1].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[3, 1].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[3, 1].legend()
ax[3, 1].title.set_text("Departure/Arrival time convenient")

x_ = np.sort(df["Ease of Online booking"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Ease of Online booking"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Ease of Online booking"])
    y_sa.append(df.loc[(df["Ease of Online booking"] == k) & (df["satisfaction"] == "satisfied")].count()["Ease of Online booking"])  
ax[4, 0].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[4, 0].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[4, 0].legend()
ax[4, 0].title.set_text("Ease of Online booking")
 
x_ = np.sort(df["Gate location"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Gate location"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Gate location"])
    y_sa.append(df.loc[(df["Gate location"] == k) & (df["satisfaction"] == "satisfied")].count()["Gate location"])  
ax[4, 1].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[4, 1].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[4, 1].legend()
ax[4, 1].title.set_text("Gate location")

x_ = np.sort(df["Food and drink"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Food and drink"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Food and drink"])
    y_sa.append(df.loc[(df["Food and drink"] == k) & (df["satisfaction"] == "satisfied")].count()["Food and drink"])  
ax[5, 0].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[5, 0].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[5, 0].legend()
ax[5, 0].title.set_text("Food and drink")

x_ = np.sort(df["Online boarding"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Online boarding"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Online boarding"])
    y_sa.append(df.loc[(df["Online boarding"] == k) & (df["satisfaction"] == "satisfied")].count()["Online boarding"])  
ax[5, 1].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[5, 1].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[5, 1].legend()
ax[5, 1].title.set_text("Online boarding")

x_ = np.sort(df["Seat comfort"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Seat comfort"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Seat comfort"])
    y_sa.append(df.loc[(df["Seat comfort"] == k) & (df["satisfaction"] == "satisfied")].count()["Seat comfort"])  
ax[6, 0].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[6, 0].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[6, 0].legend()
ax[6, 0].title.set_text("Seat comfort")

x_ = np.sort(df["Inflight entertainment"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Inflight entertainment"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Inflight entertainment"])
    y_sa.append(df.loc[(df["Inflight entertainment"] == k) & (df["satisfaction"] == "satisfied")].count()["Inflight entertainment"])  
ax[6, 1].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[6, 1].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[6, 1].legend()
ax[6, 1].title.set_text("Inflight entertainment")

x_ = np.sort(df["On-board service"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["On-board service"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["On-board service"])
    y_sa.append(df.loc[(df["On-board service"] == k) & (df["satisfaction"] == "satisfied")].count()["On-board service"])  
ax[7, 0].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[7, 0].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[7, 0].legend()
ax[7, 0].title.set_text("On-board service")

x_ = np.sort(df["Leg room service"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Leg room service"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Leg room service"])
    y_sa.append(df.loc[(df["Leg room service"] == k) & (df["satisfaction"] == "satisfied")].count()["Leg room service"])  
ax[7, 1].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[7, 1].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[7, 1].legend()
ax[7, 1].title.set_text("Leg room service")

x_ = np.sort(df["Baggage handling"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Baggage handling"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Baggage handling"])
    y_sa.append(df.loc[(df["Baggage handling"] == k) & (df["satisfaction"] == "satisfied")].count()["Baggage handling"])  
ax[8, 0].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[8, 0].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[8, 0].legend()
ax[8, 0].title.set_text("Baggage handling")

x_ = np.sort(df["Checkin service"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Checkin service"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Checkin service"])
    y_sa.append(df.loc[(df["Checkin service"] == k) & (df["satisfaction"] == "satisfied")].count()["Checkin service"])  
ax[8, 1].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[8, 1].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[8, 1].legend()
ax[8, 1].title.set_text("Checkin service")

x_ = np.sort(df["Inflight service"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Inflight service"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Inflight service"])
    y_sa.append(df.loc[(df["Inflight service"] == k) & (df["satisfaction"] == "satisfied")].count()["Inflight service"])  
ax[9, 0].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[9, 0].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[9, 0].legend()
ax[9, 0].title.set_text("Inflight service")

x_ = np.sort(df["Cleanliness"].unique())
y_sa = []
y_dissa = []
for k in x_:
    y_dissa.append(df.loc[(df["Cleanliness"] == k) & (df["satisfaction"] == "neutral or dissatisfied")].count()["Cleanliness"])
    y_sa.append(df.loc[(df["Cleanliness"] == k) & (df["satisfaction"] == "satisfied")].count()["Cleanliness"])  
ax[9, 1].bar(x_ - 0.2, y_sa, color="#4a69bd", width=0.4, label="satisfied")
ax[9, 1].bar(x_ + 0.2, y_dissa, color="#e58e26", width=0.4, label="neutral or dissatisfied")
ax[9, 1].legend()
ax[9, 1].title.set_text("Cleanliness")

delay_satis = df.loc[df["satisfaction"] == "satisfied"]["Departure Delay in Minutes"]
delay_dissatis = df.loc[df["satisfaction"] == "neutral or dissatisfied"]["Departure Delay in Minutes"]
ax[10, 0].hist([delay_satis, delay_dissatis], bins=15, color=["#4a69bd", "#e58e26"], label=["satisfied", "neutral or dissatisfied"])
ax[10, 0].legend(loc='upper right')
ax[10, 0].title.set_text("Departure Delay in Minutes")

arrival_satis = df.loc[df["satisfaction"] == "satisfied"]["Arrival Delay in Minutes"]
arrival_dissatis = df.loc[df["satisfaction"] == "neutral or dissatisfied"]["Arrival Delay in Minutes"]
ax[10, 1].hist([delay_satis, delay_dissatis], bins=15, color=["#4a69bd", "#e58e26"], label=["satisfied", "neutral or dissatisfied"])
ax[10, 1].legend(loc='upper right')
ax[10, 1].title.set_text("Arrival Delay in Minutes")

ax[11, 0].pie(df["satisfaction"].value_counts(), labels=["neutral or dissatisfied", "satisficied"], colors=["#4a69bd", "#e58e26"], autopct='%1.0f%%')
ax[11, 0].title.set_text("Satisfaction")

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# ## Handle missing data

# %%
for col in df.columns:
    if df[col].dtypes != 'object':
        df[col].fillna(df[col].median(), inplace=True)
    else:
        df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# ## Transformation data

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

# %% [markdown]
# ## Normalization data

# %%
from sklearn.preprocessing import MinMaxScaler

X = np.array(df.iloc[:, 1:-1])
y = np.array(df.iloc[:, -1])

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Split data into training/ testing set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)
print(X_train.shape)
print(y_train.shape)
# Out:
# (77928, 21)
# (77928,)

# %% [markdown]
# # Basic Machine Learning models

# %% [markdown]
# ## K-Nearest Neighbors Classifier

# %%
knn_train_score = []
knn_test_score = []
knn_setup = ["k=1", "k=3", "k=5"]
x_axis = np.arange(len(knn_setup))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

clf = KNeighborsClassifier(n_neighbors=1)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

knn_train_score.append(clf.score(X_train, y_train))
knn_test_score.append(clf.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93     14677
#            1       0.93      0.89      0.91     11299
#
#     accuracy                           0.92     25976
#    macro avg       0.92      0.92      0.92     25976
# weighted avg       0.92      0.92      0.92     25976

# %%
clf = KNeighborsClassifier(n_neighbors=3)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

knn_train_score.append(clf.score(X_train, y_train))
knn_test_score.append(clf.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     14677
#            1       0.95      0.89      0.92     11299
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
clf = KNeighborsClassifier(n_neighbors=5)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

knn_train_score.append(clf.score(X_train, y_train))
knn_test_score.append(clf.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94     14677
#            1       0.95      0.89      0.92     11299
#
#     accuracy                           0.93     25976
#    macro avg       0.94      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %% [markdown]
# ### Bảng so sánh training score và testing score của KNN với các giá trị k khác nhau

# %%
plt.plot(x_axis, knn_train_score, color="#4a69bd", label="Training Score")
plt.plot(x_axis, knn_test_score, color="#e58e26", label="Testing Score")
plt.xticks(x_axis, knn_setup)
plt.xlabel("K neighbors value")
plt.ylabel("Score")
plt.legend()
plt.show()

# %% [markdown]
# ## Decision Tree Classifier

# %% [markdown]
# ### Decision Tree with different criterion

# %%
criterion = ["gini", "entropy", "log_loss"]
training_score = []
testing_score = []

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(criterion="gini")
clf.fit(X_train, y_train)

training_score.append(clf.score(X_train, y_train))
testing_score.append(clf.score(X_test, y_test))

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     14677
#            1       0.94      0.94      0.94     11299
#
#     accuracy                           0.95     25976
#    macro avg       0.95      0.95      0.95     25976
# weighted avg       0.95      0.95      0.95     25976

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(criterion="entropy")
clf.fit(X_train, y_train)

training_score.append(clf.score(X_train, y_train))
testing_score.append(clf.score(X_test, y_test))

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     14677
#            1       0.94      0.94      0.94     11299
#
#     accuracy                           0.95     25976
#    macro avg       0.95      0.95      0.95     25976
# weighted avg       0.95      0.95      0.95     25976

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(criterion="log_loss")
clf.fit(X_train, y_train)

training_score.append(clf.score(X_train, y_train))
testing_score.append(clf.score(X_test, y_test))

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     14677
#            1       0.94      0.94      0.94     11299
#
#     accuracy                           0.95     25976
#    macro avg       0.95      0.95      0.95     25976
# weighted avg       0.95      0.95      0.95     25976

# %%
plt.plot(criterion, training_score, color="#4a69bd", label="Training Score")
plt.plot(criterion, testing_score, color="#e58e26", label="Testing Score")
plt.xlabel("Type of criterion")
plt.ylabel("Score")
plt.title("Decision Tree Classifier")
plt.legend()
plt.show()

# %% [markdown]
# ### Decision Tree Classifier with different max_depth value and criterion='entropy'

# %%
max_depth = [3, 5, 7, 9, 13, 15, 20, 22]
training_score = []
testing_score = []

for k in max_depth:
    clf = DecisionTreeClassifier(criterion="entropy", max_depth=k)
    clf.fit(X_train, y_train)
    training_score.append(clf.score(X_train, y_train))
    testing_score.append(clf.score(X_test, y_test))

plt.plot(max_depth, training_score, label="Training Score")
plt.plot(max_depth, testing_score, label="Testing Score")
plt.xlabel("Max Depth Values")
plt.ylabel("Score")
plt.legend()
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=100, solver='liblinear', penalty='l2', C=0.1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     14677
#            1       0.87      0.84      0.85     11299
#
#     accuracy                           0.88     25976
#    macro avg       0.88      0.87      0.87     25976
# weighted avg       0.88      0.88      0.88     25976

# %% [markdown]
# ## Naive Bayes

# %%
type_NB = ["Gassian", "Bernoulli", "Multinomial", "Complement", "Categorical"]
test_score = []

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

test_score.append(model.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88     14677
#            1       0.86      0.82      0.84     11299
#
#     accuracy                           0.86     25976
#    macro avg       0.86      0.86      0.86     25976
# weighted avg       0.86      0.86      0.86     25976

# %% [markdown]
# ### Bernoulli Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

model = BernoulliNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

test_score.append(model.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.80     14677
#            1       0.73      0.78      0.75     11299
#
#     accuracy                           0.78     25976
#    macro avg       0.77      0.78      0.77     25976
# weighted avg       0.78      0.78      0.78     25976

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

test_score.append(model.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83     14677
#            1       0.78      0.78      0.78     11299
#
#     accuracy                           0.81     25976
#    macro avg       0.81      0.81      0.81     25976
# weighted avg       0.81      0.81      0.81     25976

# %% [markdown]
# ### Complement Naive Bayes

# %%
from sklearn.naive_bayes import ComplementNB

model = ComplementNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

test_score.append(model.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.82     14677
#            1       0.74      0.83      0.78     11299
#
#     accuracy                           0.80     25976
#    macro avg       0.80      0.80      0.80     25976
# weighted avg       0.81      0.80      0.80     25976

# %% [markdown]
# ### Categorical Naive Bayes

# %%
from sklearn.naive_bayes import ComplementNB

model = ComplementNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

test_score.append(model.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.82     14677
#            1       0.74      0.83      0.78     11299
#
#     accuracy                           0.80     25976
#    macro avg       0.80      0.80      0.80     25976
# weighted avg       0.81      0.80      0.80     25976

# %% [markdown]
# ## Compare testing score of different Naive Bayes models

# %%
plt.plot(type_NB, test_score)
plt.xlabel("Type of Naive Bayes")
plt.ylabel("Testing Score")
plt.show()

# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# ### With kernel is "linear"

# %%
from sklearn.svm import SVC

svc = SVC(kernel="linear", C=1.)
svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90     14677
#            1       0.88      0.83      0.86     11299
#
#     accuracy                           0.88     25976
#    macro avg       0.88      0.87      0.88     25976
# weighted avg       0.88      0.88      0.88     25976

# %% [markdown]
# ### With kernel is "poly"

# %%
from sklearn.svm import SVC

svc = SVC(kernel="poly", C=1.)
svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96     14677
#            1       0.96      0.92      0.94     11299
#
#     accuracy                           0.95     25976
#    macro avg       0.95      0.95      0.95     25976
# weighted avg       0.95      0.95      0.95     25976

# %% [markdown]
# ### With kernel is "rbf"

# %%
from sklearn.svm import SVC

svc = SVC(kernel="rbf", C=1.)
svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     14677
#            1       0.96      0.93      0.94     11299
#
#     accuracy                           0.95     25976
#    macro avg       0.95      0.95      0.95     25976
# weighted avg       0.95      0.95      0.95     25976

# %% [markdown]
# # Ensemble Learning

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100, criterion="entropy", max_depth=16)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     14677
#            1       0.97      0.94      0.95     11299
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %% [markdown]
# ## Adaboost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

clf = AdaBoostClassifier(n_estimators=100)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94     14677
#            1       0.92      0.91      0.92     11299
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %% [markdown]
# ## Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

clf = BaggingClassifier()

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     14677
#            1       0.97      0.94      0.95     11299
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier()

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     14677
#            1       0.95      0.92      0.93     11299
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %% [markdown]
# # Prevent Overfitting with Basic ML Models

# %% [markdown]
# ## K-Nearest Neighbors Classifier
#
# Để tránh overfitting đối với mô hình KNN, chúng ta sẽ chọn 1 giá trị k phù hợp (thay vì mặc định k=1). Framework GridSearchCV trong thư viện sklearn sẽ hỗ trợ chúng ta chọn ra giá trị k thích hợp cho mô hình.

# %%
from sklearn.model_selection import GridSearchCV

clf_knn = KNeighborsClassifier(weights="distance")

param_grid = {'n_neighbors': np.arange(1, 25)}
knn_gscv = GridSearchCV(clf_knn, param_grid, cv=9)

knn_gscv.fit(X_train, y_train)

knn_gscv.best_params_
# Out:
# {'n_neighbors': 12}

# %%
clf = KNeighborsClassifier(n_neighbors=12, weights="distance")
clf.fit(X_train, y_train)
clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     14677
#            1       0.95      0.92      0.93     11299
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %% [markdown]
# ## Decision Tree Classifier
#
# Để tránh overfitting với Decision Tree, chúng ta sẽ giới hạn độ sâu của các nhánh, hay nói cách khác là giới hạn số lượng feature được sử dụng để split.

# %%
max_depth_values = np.arange(1, len(df.columns)-1)
testing_score = []

for max_depth in max_depth_values:
    clf = DecisionTreeClassifier(criterion="entropy", max_depth=max_depth)
    clf.fit(X_train, y_train)
    testing_score.append(clf.score(X_test, y_test))

print("Maximum Testing Score with max_depth =", max_depth_values[testing_score.index(max(testing_score))])

plt.plot(max_depth_values, testing_score)
plt.xlabel("Max depth values")
plt.ylabel("Testing Score")
plt.show()
# Out:
# Maximum Testing Score with max_depth = 17

# %% [markdown]
# ## Logistic Regression
#
# Đối với Logistic Regression, ta sử dụng LogisticRegressionCV, để áp dụng Cross-validation vào mô hình nhầm tránh overfiting

# %%
from sklearn.linear_model import LogisticRegressionCV

clf = LogisticRegressionCV(cv=9, random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     14677
#            1       0.87      0.84      0.86     11299
#
#     accuracy                           0.88     25976
#    macro avg       0.88      0.87      0.87     25976
# weighted avg       0.88      0.88      0.88     25976

# %% [markdown]
# ## Support Vector Machine
#
# Để tránh overfiting đối với SVM, ta set giá trị C để điều chỉnh margin giữa các class nhầm maximum-margin.

# %%
from sklearn.svm import SVC

svc = SVC(kernel="rbf", C=5.)
svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     14677
#            1       0.96      0.93      0.95     11299
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.95      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %% [markdown]
# # Neural Network

# %%
from tensorflow.keras.utils import to_categorical
y_train_cat = to_categorical(y_train)

# %% [markdown]
# ## Feed Forward Neural Network

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train_cat, epochs=100, batch_size=1028, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/100
# 69/69 - 1s - loss: 0.4271 - accuracy: 0.8235 - val_loss: 0.3013 - val_accuracy: 0.8834 - 947ms/epoch - 14ms/step
# Epoch 2/100
# 69/69 - 0s - loss: 0.2574 - accuracy: 0.8972 - val_loss: 0.1961 - val_accuracy: 0.9249 - 198ms/epoch - 3ms/step
# Epoch 3/100
# 69/69 - 0s - loss: 0.1825 - accuracy: 0.9276 - val_loss: 0.1571 - val_accuracy: 0.9384 - 204ms/epoch - 3ms/step
# Epoch 4/100
# 69/69 - 0s - loss: 0.1587 - accuracy: 0.9351 - val_loss: 0.1467 - val_accuracy: 0.9415 - 210ms/epoch - 3ms/step
# Epoch 5/100
# 69/69 - 0s - loss: 0.1436 - accuracy: 0.9419 - val_loss: 0.1363 - val_accuracy: 0.9451 - 206ms/epoch - 3ms/step
# Epoch 6/100
# 69/69 - 0s - loss: 0.1391 - accuracy: 0.9431 - val_loss: 0.1362 - val_accuracy: 0.9448 - 207ms/epoch - 3ms/step
# Epoch 7/100
# 69/69 - 0s - loss: 0.1323 - accuracy: 0.9461 - val_loss: 0.1298 - val_accuracy: 0.9476 - 212ms/epoch - 3ms/step
# Epoch 8/100
# 69/69 - 0s - loss: 0.1274 - accuracy: 0.9479 - val_loss: 0.1275 - val_accuracy: 0.9471 - 208ms/epoch - 3ms/step
# Epoch 9/100
# 69/69 - 0s - loss: 0.1242 - accuracy: 0.9485 - val_loss: 0.1276 - val_accuracy: 0.9498 - 202ms/epoch - 3ms/step
# Epoch 10/100
# 69/69 - 0s - loss: 0.1207 - accuracy: 0.9504 - val_loss: 0.1194 - val_accuracy: 0.9509 - 206ms/epoch - 3ms/step
# Epoch 11/100
# 69/69 - 0s - loss: 0.1174 - accuracy: 0.9516 - val_loss: 0.1183 - val_accuracy: 0.9503 - 203ms/epoch - 3ms/step
# Epoch 12/100
# 69/69 - 0s - loss: 0.1138 - accuracy: 0.9525 - val_loss: 0.1199 - val_accuracy: 0.9534 - 205ms/epoch - 3ms/step
# Epoch 13/100
# 69/69 - 0s - loss: 0.1156 - accuracy: 0.9510 - val_loss: 0.1143 - val_accuracy: 0.9533 - 213ms/epoch - 3ms/step
# Epoch 14/100
# 69/69 - 0s - loss: 0.1094 - accuracy: 0.9547 - val_loss: 0.1197 - val_accuracy: 0.9529 - 202ms/epoch - 3ms/step
# Epoch 15/100
# 69/69 - 0s - loss: 0.1095 - accuracy: 0.9543 - val_loss: 0.1131 - val_accuracy: 0.9553 - 205ms/epoch - 3ms/step
# Epoch 16/100
# 69/69 - 0s - loss: 0.1075 - accuracy: 0.9551 - val_loss: 0.1069 - val_accuracy: 0.9583 - 210ms/epoch - 3ms/step
# Epoch 17/100
# 69/69 - 0s - loss: 0.1051 - accuracy: 0.9561 - val_loss: 0.1106 - val_accuracy: 0.9543 - 208ms/epoch - 3ms/step
# Epoch 18/100
# 69/69 - 0s - loss: 0.1034 - accuracy: 0.9560 - val_loss: 0.1077 - val_accuracy: 0.9565 - 205ms/epoch - 3ms/step
# Epoch 19/100
# 69/69 - 0s - loss: 0.1043 - accuracy: 0.9566 - val_loss: 0.1097 - val_accuracy: 0.9574 - 207ms/epoch - 3ms/step
# Epoch 20/100
# 69/69 - 0s - loss: 0.1022 - accuracy: 0.9569 - val_loss: 0.1065 - val_accuracy: 0.9575 - 203ms/epoch - 3ms/step
# Epoch 21/100
# 69/69 - 0s - loss: 0.1013 - accuracy: 0.9576 - val_loss: 0.1095 - val_accuracy: 0.9571 - 202ms/epoch - 3ms/step
# Epoch 22/100
# 69/69 - 0s - loss: 0.1041 - accuracy: 0.9560 - val_loss: 0.1077 - val_accuracy: 0.9565 - 207ms/epoch - 3ms/step
# Epoch 23/100
# 69/69 - 0s - loss: 0.0981 - accuracy: 0.9590 - val_loss: 0.1047 - val_accuracy: 0.9575 - 207ms/epoch - 3ms/step
# Epoch 24/100
# 69/69 - 0s - loss: 0.0989 - accuracy: 0.9578 - val_loss: 0.1372 - val_accuracy: 0.9322 - 225ms/epoch - 3ms/step
# Epoch 25/100
# 69/69 - 0s - loss: 0.0987 - accuracy: 0.9575 - val_loss: 0.1014 - val_accuracy: 0.9575 - 206ms/epoch - 3ms/step
# Epoch 26/100
# 69/69 - 0s - loss: 0.1010 - accuracy: 0.9561 - val_loss: 0.1095 - val_accuracy: 0.9574 - 205ms/epoch - 3ms/step
# Epoch 27/100
# 69/69 - 0s - loss: 0.0966 - accuracy: 0.9592 - val_loss: 0.0991 - val_accuracy: 0.9593 - 203ms/epoch - 3ms/step
# Epoch 28/100
# 69/69 - 0s - loss: 0.0943 - accuracy: 0.9598 - val_loss: 0.1047 - val_accuracy: 0.9586 - 224ms/epoch - 3ms/step
# Epoch 29/100
# 69/69 - 0s - loss: 0.0974 - accuracy: 0.9585 - val_loss: 0.1008 - val_accuracy: 0.9602 - 218ms/epoch - 3ms/step
# Epoch 30/100
# 69/69 - 0s - loss: 0.0933 - accuracy: 0.9607 - val_loss: 0.1019 - val_accuracy: 0.9602 - 211ms/epoch - 3ms/step
# Epoch 31/100
# 69/69 - 0s - loss: 0.0943 - accuracy: 0.9595 - val_loss: 0.1057 - val_accuracy: 0.9565 - 222ms/epoch - 3ms/step
# Epoch 32/100
# 69/69 - 0s - loss: 0.0956 - accuracy: 0.9586 - val_loss: 0.0987 - val_accuracy: 0.9602 - 208ms/epoch - 3ms/step
# Epoch 33/100
# 69/69 - 0s - loss: 0.0934 - accuracy: 0.9598 - val_loss: 0.1014 - val_accuracy: 0.9601 - 208ms/epoch - 3ms/step
# Epoch 34/100
# 69/69 - 0s - loss: 0.0928 - accuracy: 0.9603 - val_loss: 0.0998 - val_accuracy: 0.9606 - 208ms/epoch - 3ms/step
# Epoch 35/100
# 69/69 - 0s - loss: 0.0912 - accuracy: 0.9613 - val_loss: 0.0987 - val_accuracy: 0.9621 - 223ms/epoch - 3ms/step
# Epoch 36/100
# 69/69 - 0s - loss: 0.0907 - accuracy: 0.9615 - val_loss: 0.0969 - val_accuracy: 0.9611 - 218ms/epoch - 3ms/step
# Epoch 37/100
# 69/69 - 0s - loss: 0.0908 - accuracy: 0.9609 - val_loss: 0.0963 - val_accuracy: 0.9616 - 214ms/epoch - 3ms/step
# Epoch 38/100
# 69/69 - 0s - loss: 0.0914 - accuracy: 0.9611 - val_loss: 0.1114 - val_accuracy: 0.9491 - 221ms/epoch - 3ms/step
# Epoch 39/100
# 69/69 - 0s - loss: 0.0896 - accuracy: 0.9613 - val_loss: 0.0951 - val_accuracy: 0.9621 - 221ms/epoch - 3ms/step
# Epoch 40/100
# 69/69 - 0s - loss: 0.0895 - accuracy: 0.9616 - val_loss: 0.0974 - val_accuracy: 0.9600 - 222ms/epoch - 3ms/step
# Epoch 41/100
# 69/69 - 0s - loss: 0.0904 - accuracy: 0.9612 - val_loss: 0.1000 - val_accuracy: 0.9580 - 225ms/epoch - 3ms/step
# Epoch 42/100
# 69/69 - 0s - loss: 0.0879 - accuracy: 0.9626 - val_loss: 0.0987 - val_accuracy: 0.9603 - 221ms/epoch - 3ms/step
# Epoch 43/100
# 69/69 - 0s - loss: 0.0880 - accuracy: 0.9621 - val_loss: 0.0947 - val_accuracy: 0.9627 - 220ms/epoch - 3ms/step
# Epoch 44/100
# 69/69 - 0s - loss: 0.0884 - accuracy: 0.9622 - val_loss: 0.0944 - val_accuracy: 0.9627 - 219ms/epoch - 3ms/step
# Epoch 45/100
# 69/69 - 0s - loss: 0.0882 - accuracy: 0.9621 - val_loss: 0.0969 - val_accuracy: 0.9621 - 225ms/epoch - 3ms/step
# Epoch 46/100
# 69/69 - 0s - loss: 0.0872 - accuracy: 0.9628 - val_loss: 0.0939 - val_accuracy: 0.9632 - 223ms/epoch - 3ms/step
# Epoch 47/100
# 69/69 - 0s - loss: 0.0861 - accuracy: 0.9635 - val_loss: 0.1001 - val_accuracy: 0.9565 - 219ms/epoch - 3ms/step
# Epoch 48/100
# 69/69 - 0s - loss: 0.0893 - accuracy: 0.9614 - val_loss: 0.0966 - val_accuracy: 0.9603 - 227ms/epoch - 3ms/step
# Epoch 49/100
# 69/69 - 0s - loss: 0.0881 - accuracy: 0.9624 - val_loss: 0.0982 - val_accuracy: 0.9609 - 219ms/epoch - 3ms/step
# Epoch 50/100
# 69/69 - 0s - loss: 0.0855 - accuracy: 0.9633 - val_loss: 0.0951 - val_accuracy: 0.9623 - 203ms/epoch - 3ms/step
# Epoch 51/100
# 69/69 - 0s - loss: 0.0844 - accuracy: 0.9632 - val_loss: 0.0948 - val_accuracy: 0.9625 - 206ms/epoch - 3ms/step
# Epoch 52/100
# 69/69 - 0s - loss: 0.0844 - accuracy: 0.9638 - val_loss: 0.0955 - val_accuracy: 0.9627 - 204ms/epoch - 3ms/step
# Epoch 53/100
# 69/69 - 0s - loss: 0.0897 - accuracy: 0.9611 - val_loss: 0.1002 - val_accuracy: 0.9600 - 202ms/epoch - 3ms/step
# Epoch 54/100
# 69/69 - 0s - loss: 0.0850 - accuracy: 0.9634 - val_loss: 0.1137 - val_accuracy: 0.9458 - 223ms/epoch - 3ms/step
# Epoch 55/100
# 69/69 - 0s - loss: 0.0842 - accuracy: 0.9639 - val_loss: 0.1047 - val_accuracy: 0.9561 - 221ms/epoch - 3ms/step
# Epoch 56/100
# 69/69 - 0s - loss: 0.0837 - accuracy: 0.9639 - val_loss: 0.0957 - val_accuracy: 0.9628 - 221ms/epoch - 3ms/step
# Epoch 57/100
# 69/69 - 0s - loss: 0.0838 - accuracy: 0.9635 - val_loss: 0.0946 - val_accuracy: 0.9639 - 215ms/epoch - 3ms/step
# Epoch 58/100
# 69/69 - 0s - loss: 0.0841 - accuracy: 0.9641 - val_loss: 0.0947 - val_accuracy: 0.9630 - 225ms/epoch - 3ms/step
# Epoch 59/100
# 69/69 - 0s - loss: 0.0836 - accuracy: 0.9634 - val_loss: 0.0973 - val_accuracy: 0.9623 - 215ms/epoch - 3ms/step
# Epoch 60/100
# 69/69 - 0s - loss: 0.0811 - accuracy: 0.9648 - val_loss: 0.0974 - val_accuracy: 0.9625 - 224ms/epoch - 3ms/step
# Epoch 61/100
# 69/69 - 0s - loss: 0.0880 - accuracy: 0.9616 - val_loss: 0.1015 - val_accuracy: 0.9616 - 211ms/epoch - 3ms/step
# Epoch 62/100
# 69/69 - 0s - loss: 0.0830 - accuracy: 0.9645 - val_loss: 0.0931 - val_accuracy: 0.9637 - 218ms/epoch - 3ms/step
# Epoch 63/100
# 69/69 - 0s - loss: 0.0816 - accuracy: 0.9645 - val_loss: 0.0953 - val_accuracy: 0.9636 - 211ms/epoch - 3ms/step
# Epoch 64/100
# 69/69 - 0s - loss: 0.0831 - accuracy: 0.9636 - val_loss: 0.0992 - val_accuracy: 0.9595 - 221ms/epoch - 3ms/step
# Epoch 65/100
# 69/69 - 0s - loss: 0.0812 - accuracy: 0.9653 - val_loss: 0.0949 - val_accuracy: 0.9621 - 215ms/epoch - 3ms/step
# Epoch 66/100
# 69/69 - 0s - loss: 0.0825 - accuracy: 0.9646 - val_loss: 0.0959 - val_accuracy: 0.9624 - 215ms/epoch - 3ms/step
# Epoch 67/100
# 69/69 - 0s - loss: 0.0814 - accuracy: 0.9654 - val_loss: 0.0949 - val_accuracy: 0.9625 - 208ms/epoch - 3ms/step
# Epoch 68/100
# 69/69 - 0s - loss: 0.0816 - accuracy: 0.9646 - val_loss: 0.0943 - val_accuracy: 0.9619 - 199ms/epoch - 3ms/step
# Epoch 69/100
# 69/69 - 0s - loss: 0.0850 - accuracy: 0.9633 - val_loss: 0.0963 - val_accuracy: 0.9628 - 220ms/epoch - 3ms/step
# Epoch 70/100
# 69/69 - 0s - loss: 0.0794 - accuracy: 0.9658 - val_loss: 0.1004 - val_accuracy: 0.9600 - 214ms/epoch - 3ms/step
# Epoch 71/100
# 69/69 - 0s - loss: 0.0811 - accuracy: 0.9649 - val_loss: 0.0958 - val_accuracy: 0.9628 - 211ms/epoch - 3ms/step
# Epoch 72/100
# 69/69 - 0s - loss: 0.0819 - accuracy: 0.9640 - val_loss: 0.0973 - val_accuracy: 0.9621 - 195ms/epoch - 3ms/step
# Epoch 73/100
# 69/69 - 0s - loss: 0.0815 - accuracy: 0.9645 - val_loss: 0.0936 - val_accuracy: 0.9625 - 220ms/epoch - 3ms/step
# Epoch 74/100
# 69/69 - 0s - loss: 0.0783 - accuracy: 0.9659 - val_loss: 0.0965 - val_accuracy: 0.9625 - 217ms/epoch - 3ms/step
# Epoch 75/100
# 69/69 - 0s - loss: 0.0782 - accuracy: 0.9662 - val_loss: 0.0982 - val_accuracy: 0.9623 - 221ms/epoch - 3ms/step
# Epoch 76/100
# 69/69 - 0s - loss: 0.0787 - accuracy: 0.9661 - val_loss: 0.0957 - val_accuracy: 0.9625 - 224ms/epoch - 3ms/step
# Epoch 77/100
# 69/69 - 0s - loss: 0.0783 - accuracy: 0.9657 - val_loss: 0.0988 - val_accuracy: 0.9620 - 209ms/epoch - 3ms/step
# Epoch 78/100
# 69/69 - 0s - loss: 0.0795 - accuracy: 0.9652 - val_loss: 0.1011 - val_accuracy: 0.9610 - 222ms/epoch - 3ms/step
# Epoch 79/100
# 69/69 - 0s - loss: 0.0771 - accuracy: 0.9670 - val_loss: 0.0979 - val_accuracy: 0.9615 - 206ms/epoch - 3ms/step
# Epoch 80/100
# 69/69 - 0s - loss: 0.0793 - accuracy: 0.9656 - val_loss: 0.0955 - val_accuracy: 0.9637 - 221ms/epoch - 3ms/step
# Epoch 81/100
# 69/69 - 0s - loss: 0.0803 - accuracy: 0.9653 - val_loss: 0.0941 - val_accuracy: 0.9632 - 211ms/epoch - 3ms/step
# Epoch 82/100
# 69/69 - 0s - loss: 0.0771 - accuracy: 0.9670 - val_loss: 0.0975 - val_accuracy: 0.9632 - 205ms/epoch - 3ms/step
# Epoch 83/100
# 69/69 - 0s - loss: 0.0776 - accuracy: 0.9666 - val_loss: 0.0953 - val_accuracy: 0.9628 - 214ms/epoch - 3ms/step
# Epoch 84/100
# 69/69 - 0s - loss: 0.0789 - accuracy: 0.9657 - val_loss: 0.1104 - val_accuracy: 0.9566 - 213ms/epoch - 3ms/step
# Epoch 85/100
# 69/69 - 0s - loss: 0.0772 - accuracy: 0.9664 - val_loss: 0.0929 - val_accuracy: 0.9648 - 214ms/epoch - 3ms/step
# Epoch 86/100
# 69/69 - 0s - loss: 0.0765 - accuracy: 0.9672 - val_loss: 0.0946 - val_accuracy: 0.9627 - 212ms/epoch - 3ms/step
# Epoch 87/100
# 69/69 - 0s - loss: 0.0765 - accuracy: 0.9667 - val_loss: 0.0969 - val_accuracy: 0.9625 - 213ms/epoch - 3ms/step
# Epoch 88/100
# 69/69 - 0s - loss: 0.0787 - accuracy: 0.9659 - val_loss: 0.0967 - val_accuracy: 0.9630 - 215ms/epoch - 3ms/step
# Epoch 89/100
# 69/69 - 0s - loss: 0.0784 - accuracy: 0.9659 - val_loss: 0.0986 - val_accuracy: 0.9624 - 211ms/epoch - 3ms/step
# Epoch 90/100
# 69/69 - 0s - loss: 0.0766 - accuracy: 0.9668 - val_loss: 0.0951 - val_accuracy: 0.9629 - 201ms/epoch - 3ms/step
# Epoch 91/100
# 69/69 - 0s - loss: 0.0758 - accuracy: 0.9668 - val_loss: 0.0969 - val_accuracy: 0.9633 - 212ms/epoch - 3ms/step
# Epoch 92/100
# 69/69 - 0s - loss: 0.0746 - accuracy: 0.9674 - val_loss: 0.0967 - val_accuracy: 0.9611 - 210ms/epoch - 3ms/step
# Epoch 93/100
# 69/69 - 0s - loss: 0.0759 - accuracy: 0.9678 - val_loss: 0.1106 - val_accuracy: 0.9542 - 205ms/epoch - 3ms/step
# Epoch 94/100
# 69/69 - 0s - loss: 0.0764 - accuracy: 0.9668 - val_loss: 0.0953 - val_accuracy: 0.9621 - 207ms/epoch - 3ms/step
# Epoch 95/100
# 69/69 - 0s - loss: 0.0791 - accuracy: 0.9651 - val_loss: 0.1077 - val_accuracy: 0.9582 - 212ms/epoch - 3ms/step
# Epoch 96/100
# 69/69 - 0s - loss: 0.0756 - accuracy: 0.9670 - val_loss: 0.1013 - val_accuracy: 0.9609 - 203ms/epoch - 3ms/step
# Epoch 97/100
# 69/69 - 0s - loss: 0.0740 - accuracy: 0.9683 - val_loss: 0.0976 - val_accuracy: 0.9620 - 205ms/epoch - 3ms/step
# Epoch 98/100
# 69/69 - 0s - loss: 0.0747 - accuracy: 0.9674 - val_loss: 0.0974 - val_accuracy: 0.9627 - 203ms/epoch - 3ms/step
# Epoch 99/100
# 69/69 - 0s - loss: 0.0752 - accuracy: 0.9673 - val_loss: 0.0957 - val_accuracy: 0.9651 - 212ms/epoch - 3ms/step
# Epoch 100/100
# 69/69 - 0s - loss: 0.0752 - accuracy: 0.9676 - val_loss: 0.0970 - val_accuracy: 0.9638 - 199ms/epoch - 3ms/step

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 812/812 [==============================] - 1s 861us/step

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     14677
#            1       0.98      0.92      0.95     11299
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.95      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %% [markdown]
# ## Wide and Deep Neural Network

# %%
import tensorflow as tf

normalization_layer = tf.keras.layers.Normalization()
hidden_layer1 = tf.keras.layers.Dense(64, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(32, activation="relu")
hidden_layer3 = tf.keras.layers.Dense(16, activation="relu")
concat_layer = tf.keras.layers.Concatenate()
output_layer = tf.keras.layers.Dense(2, activation="softmax")

input_ = tf.keras.layers.Input(shape=X_train.shape[1:])
normalized = normalization_layer(input_)
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)
hidden3 = hidden_layer3(hidden2)
concat = concat_layer([normalized, hidden3])
output = output_layer(concat)

model = tf.keras.Model(inputs=[input_], outputs=[output])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
normalization_layer.adapt(X_train)

# %%
history = model.fit(X_train, y_train_cat, epochs=100, batch_size=2056, validation_split=0.1)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5678 - accuracy: 0.7296 - val_loss: 0.4078 - val_accuracy: 0.8325
# Epoch 2/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3389 - accuracy: 0.8679 - val_loss: 0.2729 - val_accuracy: 0.8985
# Epoch 3/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2546 - accuracy: 0.9016 - val_loss: 0.2152 - val_accuracy: 0.9175
# Epoch 4/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2131 - accuracy: 0.9156 - val_loss: 0.1877 - val_accuracy: 0.9261
# Epoch 5/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1893 - accuracy: 0.9241 - val_loss: 0.1690 - val_accuracy: 0.9358
# Epoch 6/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1726 - accuracy: 0.9311 - val_loss: 0.1576 - val_accuracy: 0.9405
# Epoch 7/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1608 - accuracy: 0.9350 - val_loss: 0.1486 - val_accuracy: 0.9439
# Epoch 8/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1529 - accuracy: 0.9382 - val_loss: 0.1436 - val_accuracy: 0.9437
# Epoch 9/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9415 - val_loss: 0.1371 - val_accuracy: 0.9451
# Epoch 10/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1408 - accuracy: 0.9435 - val_loss: 0.1345 - val_accuracy: 0.9450
# Epoch 11/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.9451 - val_loss: 0.1294 - val_accuracy: 0.9480
# Epoch 12/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1308 - accuracy: 0.9472 - val_loss: 0.1283 - val_accuracy: 0.9491
# Epoch 13/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1285 - accuracy: 0.9479 - val_loss: 0.1227 - val_accuracy: 0.9515
# Epoch 14/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1238 - accuracy: 0.9497 - val_loss: 0.1210 - val_accuracy: 0.9503
# Epoch 15/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1201 - accuracy: 0.9514 - val_loss: 0.1196 - val_accuracy: 0.9506
# Epoch 16/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9523 - val_loss: 0.1165 - val_accuracy: 0.9532
# Epoch 17/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1144 - accuracy: 0.9534 - val_loss: 0.1150 - val_accuracy: 0.9542
# Epoch 18/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1127 - accuracy: 0.9538 - val_loss: 0.1140 - val_accuracy: 0.9544
# Epoch 19/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.9550 - val_loss: 0.1126 - val_accuracy: 0.9555
# Epoch 20/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1086 - accuracy: 0.9560 - val_loss: 0.1112 - val_accuracy: 0.9552
# Epoch 21/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9563 - val_loss: 0.1103 - val_accuracy: 0.9547
# Epoch 22/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1049 - accuracy: 0.9573 - val_loss: 0.1080 - val_accuracy: 0.9565
# Epoch 23/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1030 - accuracy: 0.9576 - val_loss: 0.1090 - val_accuracy: 0.9552
# Epoch 24/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.9576 - val_loss: 0.1084 - val_accuracy: 0.9557
# Epoch 25/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9578 - val_loss: 0.1081 - val_accuracy: 0.9556
# Epoch 26/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0992 - accuracy: 0.9587 - val_loss: 0.1063 - val_accuracy: 0.9577
# Epoch 27/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0988 - accuracy: 0.9586 - val_loss: 0.1076 - val_accuracy: 0.9544
# Epoch 28/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0971 - accuracy: 0.9595 - val_loss: 0.1045 - val_accuracy: 0.9571
# Epoch 29/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0967 - accuracy: 0.9589 - val_loss: 0.1032 - val_accuracy: 0.9584
# Epoch 30/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.9601 - val_loss: 0.1045 - val_accuracy: 0.9568
# Epoch 31/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0948 - accuracy: 0.9593 - val_loss: 0.1034 - val_accuracy: 0.9568
# Epoch 32/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9603 - val_loss: 0.1021 - val_accuracy: 0.9597
# Epoch 33/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0937 - accuracy: 0.9604 - val_loss: 0.1018 - val_accuracy: 0.9596
# Epoch 34/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9608 - val_loss: 0.1017 - val_accuracy: 0.9583
# Epoch 35/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0918 - accuracy: 0.9614 - val_loss: 0.1019 - val_accuracy: 0.9579
# Epoch 36/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0910 - accuracy: 0.9616 - val_loss: 0.1003 - val_accuracy: 0.9593
# Epoch 37/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0906 - accuracy: 0.9611 - val_loss: 0.1019 - val_accuracy: 0.9592
# Epoch 38/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 0.9618 - val_loss: 0.0999 - val_accuracy: 0.9592
# Epoch 39/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0894 - accuracy: 0.9619 - val_loss: 0.1011 - val_accuracy: 0.9571
# Epoch 40/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0885 - accuracy: 0.9625 - val_loss: 0.0989 - val_accuracy: 0.9610
# Epoch 41/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0887 - accuracy: 0.9621 - val_loss: 0.1001 - val_accuracy: 0.9575
# Epoch 42/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0882 - accuracy: 0.9623 - val_loss: 0.0974 - val_accuracy: 0.9603
# Epoch 43/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 0.9629 - val_loss: 0.0986 - val_accuracy: 0.9589
# Epoch 44/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0873 - accuracy: 0.9629 - val_loss: 0.0986 - val_accuracy: 0.9588
# Epoch 45/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0867 - accuracy: 0.9633 - val_loss: 0.1017 - val_accuracy: 0.9573
# Epoch 46/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0860 - accuracy: 0.9629 - val_loss: 0.0992 - val_accuracy: 0.9570
# Epoch 47/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0859 - accuracy: 0.9631 - val_loss: 0.1064 - val_accuracy: 0.9514
# Epoch 48/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0862 - accuracy: 0.9632 - val_loss: 0.0982 - val_accuracy: 0.9587
# Epoch 49/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0843 - accuracy: 0.9638 - val_loss: 0.0964 - val_accuracy: 0.9601
# Epoch 50/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0837 - accuracy: 0.9642 - val_loss: 0.0972 - val_accuracy: 0.9595
# Epoch 51/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0840 - accuracy: 0.9637 - val_loss: 0.1014 - val_accuracy: 0.9575
# Epoch 52/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9643 - val_loss: 0.0976 - val_accuracy: 0.9595
# Epoch 53/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0826 - accuracy: 0.9646 - val_loss: 0.0975 - val_accuracy: 0.9611
# Epoch 54/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0821 - accuracy: 0.9644 - val_loss: 0.0987 - val_accuracy: 0.9589
# Epoch 55/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9648 - val_loss: 0.1002 - val_accuracy: 0.9560
# Epoch 56/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0822 - accuracy: 0.9644 - val_loss: 0.0993 - val_accuracy: 0.9589
# Epoch 57/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0820 - accuracy: 0.9647 - val_loss: 0.1024 - val_accuracy: 0.9556
# Epoch 58/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0824 - accuracy: 0.9642 - val_loss: 0.0961 - val_accuracy: 0.9602
# Epoch 59/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0805 - accuracy: 0.9654 - val_loss: 0.1010 - val_accuracy: 0.9588
# Epoch 60/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9648 - val_loss: 0.0971 - val_accuracy: 0.9592
# Epoch 61/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0802 - accuracy: 0.9651 - val_loss: 0.0992 - val_accuracy: 0.9598
# Epoch 62/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9656 - val_loss: 0.0969 - val_accuracy: 0.9603
# Epoch 63/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0801 - accuracy: 0.9652 - val_loss: 0.0969 - val_accuracy: 0.9619
# Epoch 64/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0816 - accuracy: 0.9648 - val_loss: 0.0965 - val_accuracy: 0.9618
# Epoch 65/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0789 - accuracy: 0.9657 - val_loss: 0.0962 - val_accuracy: 0.9616
# Epoch 66/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9654 - val_loss: 0.0971 - val_accuracy: 0.9615
# Epoch 67/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9660 - val_loss: 0.0967 - val_accuracy: 0.9614
# Epoch 68/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0778 - accuracy: 0.9661 - val_loss: 0.0965 - val_accuracy: 0.9606
# Epoch 69/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0790 - accuracy: 0.9659 - val_loss: 0.0966 - val_accuracy: 0.9620
# Epoch 70/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0779 - accuracy: 0.9662 - val_loss: 0.0994 - val_accuracy: 0.9574
# Epoch 71/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0775 - accuracy: 0.9662 - val_loss: 0.0963 - val_accuracy: 0.9618
# Epoch 72/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0772 - accuracy: 0.9665 - val_loss: 0.0956 - val_accuracy: 0.9609
# Epoch 73/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9653 - val_loss: 0.1056 - val_accuracy: 0.9519
# Epoch 74/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0775 - accuracy: 0.9657 - val_loss: 0.0971 - val_accuracy: 0.9609
# Epoch 75/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0769 - accuracy: 0.9666 - val_loss: 0.0987 - val_accuracy: 0.9601
# Epoch 76/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0769 - accuracy: 0.9667 - val_loss: 0.0964 - val_accuracy: 0.9619
# Epoch 77/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9668 - val_loss: 0.0965 - val_accuracy: 0.9593
# Epoch 78/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0755 - accuracy: 0.9674 - val_loss: 0.0998 - val_accuracy: 0.9562
# Epoch 79/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0758 - accuracy: 0.9673 - val_loss: 0.0976 - val_accuracy: 0.9612
# Epoch 80/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0749 - accuracy: 0.9671 - val_loss: 0.0964 - val_accuracy: 0.9606
# Epoch 81/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0750 - accuracy: 0.9673 - val_loss: 0.0966 - val_accuracy: 0.9609
# Epoch 82/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9673 - val_loss: 0.0980 - val_accuracy: 0.9603
# Epoch 83/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0747 - accuracy: 0.9671 - val_loss: 0.0961 - val_accuracy: 0.9615
# Epoch 84/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9677 - val_loss: 0.0963 - val_accuracy: 0.9611
# Epoch 85/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0739 - accuracy: 0.9683 - val_loss: 0.0977 - val_accuracy: 0.9605
# Epoch 86/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0740 - accuracy: 0.9679 - val_loss: 0.0986 - val_accuracy: 0.9600
# Epoch 87/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0752 - accuracy: 0.9669 - val_loss: 0.0969 - val_accuracy: 0.9605
# Epoch 88/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0742 - accuracy: 0.9674 - val_loss: 0.0986 - val_accuracy: 0.9602
# Epoch 89/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0736 - accuracy: 0.9674 - val_loss: 0.1032 - val_accuracy: 0.9546
# Epoch 90/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9668 - val_loss: 0.1000 - val_accuracy: 0.9574
# Epoch 91/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0734 - accuracy: 0.9681 - val_loss: 0.0994 - val_accuracy: 0.9577
# Epoch 92/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0737 - accuracy: 0.9676 - val_loss: 0.0961 - val_accuracy: 0.9607
# Epoch 93/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0731 - accuracy: 0.9680 - val_loss: 0.0954 - val_accuracy: 0.9607
# Epoch 94/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0723 - accuracy: 0.9682 - val_loss: 0.0965 - val_accuracy: 0.9602
# Epoch 95/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 0.9684 - val_loss: 0.0961 - val_accuracy: 0.9607
# Epoch 96/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0723 - accuracy: 0.9681 - val_loss: 0.0965 - val_accuracy: 0.9610
# Epoch 97/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0722 - accuracy: 0.9682 - val_loss: 0.0981 - val_accuracy: 0.9595
# Epoch 98/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0723 - accuracy: 0.9683 - val_loss: 0.0984 - val_accuracy: 0.9609
# Epoch 99/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0714 - accuracy: 0.9684 - val_loss: 0.0973 - val_accuracy: 0.9607
# Epoch 100/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0714 - accuracy: 0.9682 - val_loss: 0.0969 - val_accuracy: 0.9611

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 812/812 [==============================] - 1s 882us/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     14677
#            1       0.97      0.93      0.95     11299
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.95      0.95     25976
# weighted avg       0.96      0.96      0.96     25976

# %% [markdown]
# # Neural Network LSTM

# %%
X_train_LSTM = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.layers import LSTM, Dense
model_LSTM = models.Sequential()
model_LSTM.add(LSTM(100, input_shape=(X_train_LSTM.shape[1], X_train_LSTM.shape[2])))
model_LSTM.add(Dense(32, activation="relu"))
model_LSTM.add(Dense(16, activation="relu"))
model_LSTM.add(Dense(2, activation='softmax'))

# %%
model_LSTM.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

hist = model_LSTM.fit(X_train_LSTM, y_train_cat, epochs=30, batch_size=512,  validation_split=0.1, verbose=2)
# Out:
# Epoch 1/30
# 137/137 - 9s - loss: 0.3356 - accuracy: 0.8572 - val_loss: 0.3084 - val_accuracy: 0.8698 - 9s/epoch - 63ms/step
# Epoch 2/30
# 137/137 - 7s - loss: 0.3190 - accuracy: 0.8654 - val_loss: 0.3131 - val_accuracy: 0.8639 - 7s/epoch - 51ms/step
# Epoch 3/30
# 137/137 - 7s - loss: 0.3190 - accuracy: 0.8647 - val_loss: 0.3068 - val_accuracy: 0.8723 - 7s/epoch - 49ms/step
# Epoch 4/30
# 137/137 - 7s - loss: 0.3172 - accuracy: 0.8658 - val_loss: 0.3051 - val_accuracy: 0.8717 - 7s/epoch - 49ms/step
# Epoch 5/30
# 137/137 - 7s - loss: 0.3139 - accuracy: 0.8671 - val_loss: 0.3003 - val_accuracy: 0.8746 - 7s/epoch - 49ms/step
# Epoch 6/30
# 137/137 - 7s - loss: 0.3082 - accuracy: 0.8699 - val_loss: 0.3004 - val_accuracy: 0.8746 - 7s/epoch - 49ms/step
# Epoch 7/30
# 137/137 - 6s - loss: 0.3066 - accuracy: 0.8706 - val_loss: 0.2975 - val_accuracy: 0.8762 - 6s/epoch - 47ms/step
# Epoch 8/30
# 137/137 - 6s - loss: 0.3040 - accuracy: 0.8729 - val_loss: 0.2860 - val_accuracy: 0.8817 - 6s/epoch - 47ms/step
# Epoch 9/30
# 137/137 - 6s - loss: 0.3007 - accuracy: 0.8745 - val_loss: 0.2832 - val_accuracy: 0.8848 - 6s/epoch - 46ms/step
# Epoch 10/30
# 137/137 - 6s - loss: 0.2986 - accuracy: 0.8750 - val_loss: 0.2804 - val_accuracy: 0.8835 - 6s/epoch - 46ms/step
# Epoch 11/30
# 137/137 - 6s - loss: 0.2904 - accuracy: 0.8793 - val_loss: 0.2867 - val_accuracy: 0.8814 - 6s/epoch - 46ms/step
# Epoch 12/30
# 137/137 - 6s - loss: 0.2868 - accuracy: 0.8812 - val_loss: 0.2880 - val_accuracy: 0.8813 - 6s/epoch - 46ms/step
# Epoch 13/30
# 137/137 - 6s - loss: 0.2853 - accuracy: 0.8825 - val_loss: 0.2628 - val_accuracy: 0.8922 - 6s/epoch - 46ms/step
# Epoch 14/30
# 137/137 - 6s - loss: 0.2714 - accuracy: 0.8892 - val_loss: 0.2558 - val_accuracy: 0.8977 - 6s/epoch - 46ms/step
# Epoch 15/30
# 137/137 - 6s - loss: 0.2644 - accuracy: 0.8918 - val_loss: 0.2596 - val_accuracy: 0.8963 - 6s/epoch - 47ms/step
# Epoch 16/30
# 137/137 - 6s - loss: 0.2560 - accuracy: 0.8929 - val_loss: 0.2440 - val_accuracy: 0.9013 - 6s/epoch - 47ms/step
# Epoch 17/30
# 137/137 - 6s - loss: 0.2495 - accuracy: 0.8967 - val_loss: 0.2404 - val_accuracy: 0.9022 - 6s/epoch - 46ms/step
# Epoch 18/30
# 137/137 - 6s - loss: 0.2398 - accuracy: 0.9002 - val_loss: 0.2222 - val_accuracy: 0.9111 - 6s/epoch - 46ms/step
# Epoch 19/30
# 137/137 - 6s - loss: 0.2324 - accuracy: 0.9038 - val_loss: 0.2255 - val_accuracy: 0.9072 - 6s/epoch - 46ms/step
# Epoch 20/30
# 137/137 - 6s - loss: 0.2275 - accuracy: 0.9072 - val_loss: 0.2124 - val_accuracy: 0.9131 - 6s/epoch - 47ms/step
# Epoch 21/30
# 137/137 - 6s - loss: 0.2248 - accuracy: 0.9088 - val_loss: 0.2140 - val_accuracy: 0.9117 - 6s/epoch - 46ms/step
# Epoch 22/30
# 137/137 - 7s - loss: 0.2219 - accuracy: 0.9102 - val_loss: 0.2079 - val_accuracy: 0.9157 - 7s/epoch - 48ms/step
# Epoch 23/30
# 137/137 - 6s - loss: 0.2131 - accuracy: 0.9134 - val_loss: 0.2051 - val_accuracy: 0.9184 - 6s/epoch - 46ms/step
# Epoch 24/30
# 137/137 - 6s - loss: 0.2094 - accuracy: 0.9147 - val_loss: 0.2253 - val_accuracy: 0.9094 - 6s/epoch - 46ms/step
# Epoch 25/30
# 137/137 - 6s - loss: 0.2095 - accuracy: 0.9159 - val_loss: 0.2040 - val_accuracy: 0.9171 - 6s/epoch - 46ms/step
# Epoch 26/30
# 137/137 - 6s - loss: 0.2085 - accuracy: 0.9154 - val_loss: 0.1994 - val_accuracy: 0.9199 - 6s/epoch - 46ms/step
# Epoch 27/30
# 137/137 - 6s - loss: 0.2016 - accuracy: 0.9183 - val_loss: 0.1907 - val_accuracy: 0.9239 - 6s/epoch - 47ms/step
# Epoch 28/30
# 137/137 - 7s - loss: 0.1971 - accuracy: 0.9196 - val_loss: 0.1936 - val_accuracy: 0.9242 - 7s/epoch - 48ms/step
# Epoch 29/30
# 137/137 - 7s - loss: 0.1948 - accuracy: 0.9219 - val_loss: 0.1839 - val_accuracy: 0.9283 - 7s/epoch - 48ms/step
# Epoch 30/30
# 137/137 - 6s - loss: 0.1984 - accuracy: 0.9192 - val_loss: 0.1948 - val_accuracy: 0.9236 - 6s/epoch - 47ms/step

# %%
y_pred = model_LSTM.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 812/812 [==============================] - 3s 4ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93     14677
#            1       0.95      0.86      0.90     11299
#
#     accuracy                           0.92     25976
#    macro avg       0.92      0.91      0.91     25976
# weighted avg       0.92      0.92      0.92     25976

# %% [markdown]
# # Prevent Overfiting with Neural Network
#
# Trong Neural Network để tránh overfiting, chúng ta sẽ thêm 1 lớp Dropout

# %%
model = models.Sequential()
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train_cat, epochs=100, batch_size=1028, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/100
# 69/69 - 1s - loss: 0.5931 - accuracy: 0.6807 - val_loss: 0.3638 - val_accuracy: 0.8523 - 1s/epoch - 16ms/step
# Epoch 2/100
# 69/69 - 0s - loss: 0.3667 - accuracy: 0.8534 - val_loss: 0.2934 - val_accuracy: 0.8863 - 257ms/epoch - 4ms/step
# Epoch 3/100
# 69/69 - 0s - loss: 0.2985 - accuracy: 0.8813 - val_loss: 0.2217 - val_accuracy: 0.9153 - 277ms/epoch - 4ms/step
# Epoch 4/100
# 69/69 - 0s - loss: 0.2522 - accuracy: 0.8996 - val_loss: 0.1932 - val_accuracy: 0.9258 - 286ms/epoch - 4ms/step
# Epoch 5/100
# 69/69 - 0s - loss: 0.2226 - accuracy: 0.9112 - val_loss: 0.1673 - val_accuracy: 0.9364 - 290ms/epoch - 4ms/step
# Epoch 6/100
# 69/69 - 0s - loss: 0.2043 - accuracy: 0.9181 - val_loss: 0.1520 - val_accuracy: 0.9424 - 341ms/epoch - 5ms/step
# Epoch 7/100
# 69/69 - 0s - loss: 0.1898 - accuracy: 0.9233 - val_loss: 0.1434 - val_accuracy: 0.9450 - 294ms/epoch - 4ms/step
# Epoch 8/100
# 69/69 - 0s - loss: 0.1771 - accuracy: 0.9271 - val_loss: 0.1358 - val_accuracy: 0.9476 - 290ms/epoch - 4ms/step
# Epoch 9/100
# 69/69 - 0s - loss: 0.1686 - accuracy: 0.9311 - val_loss: 0.1307 - val_accuracy: 0.9494 - 285ms/epoch - 4ms/step
# Epoch 10/100
# 69/69 - 0s - loss: 0.1625 - accuracy: 0.9340 - val_loss: 0.1294 - val_accuracy: 0.9496 - 287ms/epoch - 4ms/step
# Epoch 11/100
# 69/69 - 0s - loss: 0.1562 - accuracy: 0.9357 - val_loss: 0.1275 - val_accuracy: 0.9496 - 288ms/epoch - 4ms/step
# Epoch 12/100
# 69/69 - 0s - loss: 0.1507 - accuracy: 0.9383 - val_loss: 0.1219 - val_accuracy: 0.9514 - 286ms/epoch - 4ms/step
# Epoch 13/100
# 69/69 - 0s - loss: 0.1469 - accuracy: 0.9396 - val_loss: 0.1187 - val_accuracy: 0.9521 - 286ms/epoch - 4ms/step
# Epoch 14/100
# 69/69 - 0s - loss: 0.1438 - accuracy: 0.9399 - val_loss: 0.1187 - val_accuracy: 0.9533 - 288ms/epoch - 4ms/step
# Epoch 15/100
# 69/69 - 0s - loss: 0.1404 - accuracy: 0.9421 - val_loss: 0.1144 - val_accuracy: 0.9547 - 293ms/epoch - 4ms/step
# Epoch 16/100
# 69/69 - 0s - loss: 0.1383 - accuracy: 0.9435 - val_loss: 0.1194 - val_accuracy: 0.9525 - 287ms/epoch - 4ms/step
# Epoch 17/100
# 69/69 - 0s - loss: 0.1330 - accuracy: 0.9455 - val_loss: 0.1104 - val_accuracy: 0.9573 - 289ms/epoch - 4ms/step
# Epoch 18/100
# 69/69 - 0s - loss: 0.1312 - accuracy: 0.9463 - val_loss: 0.1118 - val_accuracy: 0.9535 - 286ms/epoch - 4ms/step
# Epoch 19/100
# 69/69 - 0s - loss: 0.1297 - accuracy: 0.9460 - val_loss: 0.1090 - val_accuracy: 0.9557 - 294ms/epoch - 4ms/step
# Epoch 20/100
# 69/69 - 0s - loss: 0.1279 - accuracy: 0.9466 - val_loss: 0.1098 - val_accuracy: 0.9560 - 291ms/epoch - 4ms/step
# Epoch 21/100
# 69/69 - 0s - loss: 0.1255 - accuracy: 0.9482 - val_loss: 0.1066 - val_accuracy: 0.9573 - 303ms/epoch - 4ms/step
# Epoch 22/100
# 69/69 - 0s - loss: 0.1251 - accuracy: 0.9470 - val_loss: 0.1075 - val_accuracy: 0.9584 - 290ms/epoch - 4ms/step
# Epoch 23/100
# 69/69 - 0s - loss: 0.1250 - accuracy: 0.9479 - val_loss: 0.1053 - val_accuracy: 0.9579 - 337ms/epoch - 5ms/step
# Epoch 24/100
# 69/69 - 0s - loss: 0.1216 - accuracy: 0.9494 - val_loss: 0.1047 - val_accuracy: 0.9583 - 313ms/epoch - 5ms/step
# Epoch 25/100
# 69/69 - 0s - loss: 0.1201 - accuracy: 0.9496 - val_loss: 0.1058 - val_accuracy: 0.9584 - 287ms/epoch - 4ms/step
# Epoch 26/100
# 69/69 - 0s - loss: 0.1197 - accuracy: 0.9499 - val_loss: 0.1009 - val_accuracy: 0.9592 - 289ms/epoch - 4ms/step
# Epoch 27/100
# 69/69 - 0s - loss: 0.1197 - accuracy: 0.9503 - val_loss: 0.1006 - val_accuracy: 0.9598 - 285ms/epoch - 4ms/step
# Epoch 28/100
# 69/69 - 0s - loss: 0.1173 - accuracy: 0.9513 - val_loss: 0.1017 - val_accuracy: 0.9587 - 288ms/epoch - 4ms/step
# Epoch 29/100
# 69/69 - 0s - loss: 0.1165 - accuracy: 0.9515 - val_loss: 0.0999 - val_accuracy: 0.9603 - 286ms/epoch - 4ms/step
# Epoch 30/100
# 69/69 - 0s - loss: 0.1152 - accuracy: 0.9526 - val_loss: 0.1003 - val_accuracy: 0.9601 - 291ms/epoch - 4ms/step
# Epoch 31/100
# 69/69 - 0s - loss: 0.1157 - accuracy: 0.9515 - val_loss: 0.0987 - val_accuracy: 0.9596 - 290ms/epoch - 4ms/step
# Epoch 32/100
# 69/69 - 0s - loss: 0.1147 - accuracy: 0.9524 - val_loss: 0.0967 - val_accuracy: 0.9607 - 284ms/epoch - 4ms/step
# Epoch 33/100
# 69/69 - 0s - loss: 0.1135 - accuracy: 0.9523 - val_loss: 0.0990 - val_accuracy: 0.9605 - 298ms/epoch - 4ms/step
# Epoch 34/100
# 69/69 - 0s - loss: 0.1119 - accuracy: 0.9530 - val_loss: 0.0986 - val_accuracy: 0.9593 - 295ms/epoch - 4ms/step
# Epoch 35/100
# 69/69 - 0s - loss: 0.1117 - accuracy: 0.9537 - val_loss: 0.0962 - val_accuracy: 0.9614 - 287ms/epoch - 4ms/step
# Epoch 36/100
# 69/69 - 0s - loss: 0.1106 - accuracy: 0.9537 - val_loss: 0.0969 - val_accuracy: 0.9611 - 289ms/epoch - 4ms/step
# Epoch 37/100
# 69/69 - 0s - loss: 0.1102 - accuracy: 0.9545 - val_loss: 0.0996 - val_accuracy: 0.9593 - 290ms/epoch - 4ms/step
# Epoch 38/100
# 69/69 - 0s - loss: 0.1103 - accuracy: 0.9531 - val_loss: 0.0960 - val_accuracy: 0.9620 - 290ms/epoch - 4ms/step
# Epoch 39/100
# 69/69 - 0s - loss: 0.1097 - accuracy: 0.9536 - val_loss: 0.0953 - val_accuracy: 0.9614 - 287ms/epoch - 4ms/step
# Epoch 40/100
# 69/69 - 0s - loss: 0.1089 - accuracy: 0.9545 - val_loss: 0.0939 - val_accuracy: 0.9632 - 341ms/epoch - 5ms/step
# Epoch 41/100
# 69/69 - 0s - loss: 0.1100 - accuracy: 0.9537 - val_loss: 0.0953 - val_accuracy: 0.9621 - 291ms/epoch - 4ms/step
# Epoch 42/100
# 69/69 - 0s - loss: 0.1084 - accuracy: 0.9542 - val_loss: 0.0947 - val_accuracy: 0.9607 - 294ms/epoch - 4ms/step
# Epoch 43/100
# 69/69 - 0s - loss: 0.1065 - accuracy: 0.9553 - val_loss: 0.0924 - val_accuracy: 0.9632 - 292ms/epoch - 4ms/step
# Epoch 44/100
# 69/69 - 0s - loss: 0.1063 - accuracy: 0.9552 - val_loss: 0.0940 - val_accuracy: 0.9625 - 286ms/epoch - 4ms/step
# Epoch 45/100
# 69/69 - 0s - loss: 0.1066 - accuracy: 0.9552 - val_loss: 0.0924 - val_accuracy: 0.9620 - 289ms/epoch - 4ms/step
# Epoch 46/100
# 69/69 - 0s - loss: 0.1066 - accuracy: 0.9549 - val_loss: 0.0935 - val_accuracy: 0.9625 - 288ms/epoch - 4ms/step
# Epoch 47/100
# 69/69 - 0s - loss: 0.1060 - accuracy: 0.9556 - val_loss: 0.0927 - val_accuracy: 0.9612 - 289ms/epoch - 4ms/step
# Epoch 48/100
# 69/69 - 0s - loss: 0.1051 - accuracy: 0.9557 - val_loss: 0.0916 - val_accuracy: 0.9628 - 287ms/epoch - 4ms/step
# Epoch 49/100
# 69/69 - 0s - loss: 0.1046 - accuracy: 0.9558 - val_loss: 0.0929 - val_accuracy: 0.9621 - 288ms/epoch - 4ms/step
# Epoch 50/100
# 69/69 - 0s - loss: 0.1051 - accuracy: 0.9566 - val_loss: 0.0918 - val_accuracy: 0.9625 - 290ms/epoch - 4ms/step
# Epoch 51/100
# 69/69 - 0s - loss: 0.1037 - accuracy: 0.9557 - val_loss: 0.0910 - val_accuracy: 0.9633 - 290ms/epoch - 4ms/step
# Epoch 52/100
# 69/69 - 0s - loss: 0.1051 - accuracy: 0.9556 - val_loss: 0.0919 - val_accuracy: 0.9627 - 288ms/epoch - 4ms/step
# Epoch 53/100
# 69/69 - 0s - loss: 0.1053 - accuracy: 0.9560 - val_loss: 0.0920 - val_accuracy: 0.9641 - 289ms/epoch - 4ms/step
# Epoch 54/100
# 69/69 - 0s - loss: 0.1030 - accuracy: 0.9572 - val_loss: 0.0929 - val_accuracy: 0.9642 - 288ms/epoch - 4ms/step
# Epoch 55/100
# 69/69 - 0s - loss: 0.1037 - accuracy: 0.9558 - val_loss: 0.0904 - val_accuracy: 0.9652 - 297ms/epoch - 4ms/step
# Epoch 56/100
# 69/69 - 0s - loss: 0.1019 - accuracy: 0.9568 - val_loss: 0.0913 - val_accuracy: 0.9633 - 288ms/epoch - 4ms/step
# Epoch 57/100
# 69/69 - 0s - loss: 0.1013 - accuracy: 0.9572 - val_loss: 0.0904 - val_accuracy: 0.9638 - 329ms/epoch - 5ms/step
# Epoch 58/100
# 69/69 - 0s - loss: 0.1020 - accuracy: 0.9570 - val_loss: 0.0899 - val_accuracy: 0.9654 - 299ms/epoch - 4ms/step
# Epoch 59/100
# 69/69 - 0s - loss: 0.1023 - accuracy: 0.9575 - val_loss: 0.0919 - val_accuracy: 0.9621 - 288ms/epoch - 4ms/step
# Epoch 60/100
# 69/69 - 0s - loss: 0.1016 - accuracy: 0.9574 - val_loss: 0.0895 - val_accuracy: 0.9629 - 285ms/epoch - 4ms/step
# Epoch 61/100
# 69/69 - 0s - loss: 0.1024 - accuracy: 0.9565 - val_loss: 0.0894 - val_accuracy: 0.9651 - 287ms/epoch - 4ms/step
# Epoch 62/100
# 69/69 - 0s - loss: 0.1012 - accuracy: 0.9572 - val_loss: 0.0904 - val_accuracy: 0.9647 - 281ms/epoch - 4ms/step
# Epoch 63/100
# 69/69 - 0s - loss: 0.1005 - accuracy: 0.9574 - val_loss: 0.0896 - val_accuracy: 0.9656 - 285ms/epoch - 4ms/step
# Epoch 64/100
# 69/69 - 0s - loss: 0.1001 - accuracy: 0.9578 - val_loss: 0.0891 - val_accuracy: 0.9645 - 284ms/epoch - 4ms/step
# Epoch 65/100
# 69/69 - 0s - loss: 0.1018 - accuracy: 0.9563 - val_loss: 0.0895 - val_accuracy: 0.9654 - 284ms/epoch - 4ms/step
# Epoch 66/100
# 69/69 - 0s - loss: 0.1000 - accuracy: 0.9578 - val_loss: 0.0933 - val_accuracy: 0.9632 - 286ms/epoch - 4ms/step
# Epoch 67/100
# 69/69 - 0s - loss: 0.1016 - accuracy: 0.9570 - val_loss: 0.0887 - val_accuracy: 0.9645 - 286ms/epoch - 4ms/step
# Epoch 68/100
# 69/69 - 0s - loss: 0.1017 - accuracy: 0.9570 - val_loss: 0.0884 - val_accuracy: 0.9647 - 284ms/epoch - 4ms/step
# Epoch 69/100
# 69/69 - 0s - loss: 0.0995 - accuracy: 0.9574 - val_loss: 0.0869 - val_accuracy: 0.9650 - 282ms/epoch - 4ms/step
# Epoch 70/100
# 69/69 - 0s - loss: 0.1000 - accuracy: 0.9572 - val_loss: 0.0890 - val_accuracy: 0.9654 - 285ms/epoch - 4ms/step
# Epoch 71/100
# 69/69 - 0s - loss: 0.0992 - accuracy: 0.9577 - val_loss: 0.0882 - val_accuracy: 0.9663 - 285ms/epoch - 4ms/step
# Epoch 72/100
# 69/69 - 0s - loss: 0.0986 - accuracy: 0.9579 - val_loss: 0.0885 - val_accuracy: 0.9647 - 285ms/epoch - 4ms/step
# Epoch 73/100
# 69/69 - 0s - loss: 0.0995 - accuracy: 0.9577 - val_loss: 0.0873 - val_accuracy: 0.9647 - 282ms/epoch - 4ms/step
# Epoch 74/100
# 69/69 - 0s - loss: 0.1004 - accuracy: 0.9577 - val_loss: 0.0865 - val_accuracy: 0.9656 - 311ms/epoch - 5ms/step
# Epoch 75/100
# 69/69 - 0s - loss: 0.0975 - accuracy: 0.9584 - val_loss: 0.0886 - val_accuracy: 0.9643 - 309ms/epoch - 4ms/step
# Epoch 76/100
# 69/69 - 0s - loss: 0.0996 - accuracy: 0.9577 - val_loss: 0.0868 - val_accuracy: 0.9666 - 288ms/epoch - 4ms/step
# Epoch 77/100
# 69/69 - 0s - loss: 0.0989 - accuracy: 0.9579 - val_loss: 0.0873 - val_accuracy: 0.9660 - 286ms/epoch - 4ms/step
# Epoch 78/100
# 69/69 - 0s - loss: 0.0983 - accuracy: 0.9588 - val_loss: 0.0863 - val_accuracy: 0.9660 - 284ms/epoch - 4ms/step
# Epoch 79/100
# 69/69 - 0s - loss: 0.0972 - accuracy: 0.9580 - val_loss: 0.0883 - val_accuracy: 0.9645 - 287ms/epoch - 4ms/step
# Epoch 80/100
# 69/69 - 0s - loss: 0.0971 - accuracy: 0.9586 - val_loss: 0.0865 - val_accuracy: 0.9648 - 282ms/epoch - 4ms/step
# Epoch 81/100
# 69/69 - 0s - loss: 0.0971 - accuracy: 0.9583 - val_loss: 0.0847 - val_accuracy: 0.9664 - 286ms/epoch - 4ms/step
# Epoch 82/100
# 69/69 - 0s - loss: 0.0969 - accuracy: 0.9588 - val_loss: 0.0878 - val_accuracy: 0.9654 - 286ms/epoch - 4ms/step
# Epoch 83/100
# 69/69 - 0s - loss: 0.0967 - accuracy: 0.9588 - val_loss: 0.0858 - val_accuracy: 0.9655 - 298ms/epoch - 4ms/step
# Epoch 84/100
# 69/69 - 0s - loss: 0.0965 - accuracy: 0.9593 - val_loss: 0.0860 - val_accuracy: 0.9661 - 287ms/epoch - 4ms/step
# Epoch 85/100
# 69/69 - 0s - loss: 0.0968 - accuracy: 0.9584 - val_loss: 0.0854 - val_accuracy: 0.9655 - 284ms/epoch - 4ms/step
# Epoch 86/100
# 69/69 - 0s - loss: 0.0972 - accuracy: 0.9587 - val_loss: 0.0870 - val_accuracy: 0.9648 - 289ms/epoch - 4ms/step
# Epoch 87/100
# 69/69 - 0s - loss: 0.0958 - accuracy: 0.9586 - val_loss: 0.0872 - val_accuracy: 0.9647 - 284ms/epoch - 4ms/step
# Epoch 88/100
# 69/69 - 0s - loss: 0.0976 - accuracy: 0.9584 - val_loss: 0.0857 - val_accuracy: 0.9654 - 286ms/epoch - 4ms/step
# Epoch 89/100
# 69/69 - 0s - loss: 0.0964 - accuracy: 0.9590 - val_loss: 0.0848 - val_accuracy: 0.9660 - 286ms/epoch - 4ms/step
# Epoch 90/100
# 69/69 - 0s - loss: 0.0956 - accuracy: 0.9592 - val_loss: 0.0865 - val_accuracy: 0.9654 - 291ms/epoch - 4ms/step
# Epoch 91/100
# 69/69 - 0s - loss: 0.0966 - accuracy: 0.9593 - val_loss: 0.0851 - val_accuracy: 0.9655 - 287ms/epoch - 4ms/step
# Epoch 92/100
# 69/69 - 0s - loss: 0.0957 - accuracy: 0.9597 - val_loss: 0.0858 - val_accuracy: 0.9660 - 328ms/epoch - 5ms/step
# Epoch 93/100
# 69/69 - 0s - loss: 0.0975 - accuracy: 0.9584 - val_loss: 0.0834 - val_accuracy: 0.9669 - 289ms/epoch - 4ms/step
# Epoch 94/100
# 69/69 - 0s - loss: 0.0956 - accuracy: 0.9592 - val_loss: 0.0841 - val_accuracy: 0.9660 - 286ms/epoch - 4ms/step
# Epoch 95/100
# 69/69 - 0s - loss: 0.0947 - accuracy: 0.9601 - val_loss: 0.0841 - val_accuracy: 0.9669 - 283ms/epoch - 4ms/step
# Epoch 96/100
# 69/69 - 0s - loss: 0.0970 - accuracy: 0.9584 - val_loss: 0.0837 - val_accuracy: 0.9666 - 285ms/epoch - 4ms/step
# Epoch 97/100
# 69/69 - 0s - loss: 0.0954 - accuracy: 0.9595 - val_loss: 0.0845 - val_accuracy: 0.9665 - 285ms/epoch - 4ms/step
# Epoch 98/100
# 69/69 - 0s - loss: 0.0954 - accuracy: 0.9595 - val_loss: 0.0846 - val_accuracy: 0.9661 - 285ms/epoch - 4ms/step
# Epoch 99/100
# 69/69 - 0s - loss: 0.0960 - accuracy: 0.9592 - val_loss: 0.0858 - val_accuracy: 0.9651 - 280ms/epoch - 4ms/step
# Epoch 100/100
# 69/69 - 0s - loss: 0.0938 - accuracy: 0.9596 - val_loss: 0.0839 - val_accuracy: 0.9668 - 283ms/epoch - 4ms/step

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 812/812 [==============================] - 1s 869us/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     14677
#            1       0.98      0.93      0.95     11299
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %% [markdown]
# # Để cải thiện độ chính xác của mô hình sau khi huấn luyện, ta có thể thực hiện các bước sau:
#
# ## Phân tích các trường hợp sai
# Bước đầu tiên là phân tích các trường hợp sai của mô hình. Điều này có thể được thực hiện bằng cách xem xét các mẫu dữ liệu mà mô hình đã dự đoán sai. Các trường hợp sai có thể được phân loại thành hai loại:
#
# - **Lỗi do bias:** Lỗi này xảy ra khi mô hình không thể nắm bắt được các mối quan hệ quan trọng trong dữ liệu. Lỗi bias thường dẫn đến việc mô hình dự đoán sai các mẫu dữ liệu mới.
# - **Lỗi do variance:** Lỗi này xảy ra khi mô hình quá khớp với tập dữ liệu huấn luyện. Lỗi variance thường dẫn đến việc mô hình dự đoán sai các mẫu dữ liệu mới.
#
# **Đề ra giải pháp**
#
# Sau khi phân tích các trường hợp sai, ta có thể đề ra các giải pháp để cải thiện độ chính xác của mô hình. Các giải pháp này có thể bao gồm:
#
# - **Thay đổi kiến trúc mô hình:** Nếu lỗi do bias, ta có thể thay đổi kiến trúc mô hình để mô hình có thể nắm bắt được các mối quan hệ quan trọng trong dữ liệu tốt hơn.
# - **Tăng cường dữ liệu:** Nếu lỗi do variance, ta có thể tăng cường dữ liệu để mô hình có thể học được các mối quan hệ tổng quát hơn.
# - **Áp dụng kỹ thuật regularize:** Kỹ thuật regularize giúp giảm thiểu sự khớp của mô hình với tập dữ liệu huấn luyện, từ đó cải thiện độ chính xác của mô hình trên tập dữ liệu mới.
#
# **Thực hiện giải pháp**
#
# Sau khi đề ra các giải pháp, ta cần thực hiện các giải pháp đó. Việc thực hiện các giải pháp có thể bao gồm:
#
# - **Tái huấn luyện mô hình với kiến trúc mới:** Nếu thay đổi kiến trúc mô hình, ta cần huấn luyện lại mô hình với tập dữ liệu huấn luyện mới.
# - **Thêm dữ liệu mới vào tập dữ liệu huấn luyện:** Nếu tăng cường dữ liệu, ta cần thêm dữ liệu mới vào tập dữ liệu huấn luyện.
# - **Áp dụng kỹ thuật regularize:** Nếu áp dụng kỹ thuật regularize, ta cần điều chỉnh các siêu tham số của kỹ thuật regularize.
#
# **Đánh giá hiệu quả**
#
# Sau khi thực hiện các giải pháp, ta cần đánh giá hiệu quả của các giải pháp đó. Việc đánh giá hiệu quả có thể được thực hiện bằng cách xem xét độ chính xác của mô hình trên tập dữ liệu kiểm tra.
#
# Nếu độ chính xác của mô hình trên tập dữ liệu kiểm tra cải thiện so với trước, thì các giải pháp đã được đề ra là hiệu quả. Nếu độ chính xác của mô hình không cải thiện, thì ta cần tiếp tục phân tích và đề ra các giải pháp khác.
#
# Dưới đây là một số ví dụ cụ thể về cách cải thiện độ chính xác của mô hình sau khi huấn luyện:
#
# - Trong trường hợp lỗi do bias, ta có thể thay đổi kiến trúc mô hình bằng cách thêm các lớp ẩn, tăng số lượng tham số của mô hình, hoặc sử dụng các kỹ thuật như dropout hoặc batch normalization.
# - Trong trường hợp lỗi do variance, ta có thể tăng cường dữ liệu bằng cách tạo các mẫu dữ liệu mới từ các mẫu dữ liệu hiện có.
# - Ta cũng có thể áp dụng kỹ thuật regularize như L1 regularization hoặc L2 regularization để giảm thiểu sự khớp của mô hình với tập dữ liệu huấn luyện.
# Việc lựa chọn giải pháp nào để cải thiện độ chính xác của mô hình phụ thuộc vào nguyên nhân gây ra lỗi của mô hình.

# %%
import seaborn as sns
from matplotlib import pyplot as plt

correlation_matrix = df.corr()
sns.set(font_scale=0.8)
plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Sau khi xem xét mối quan hệ giữa các feature ta thấy rằng:
# - Departure delays in minutes tương quan với Arrival Dealy in minutes. Lý giải cho điều này thì việc máy bay hạ cánh xuống sân bay trễ thì sẽ dẫn đến việc máy bay khởi hành chuyến bay trễ.
# - Inflight wifi service với Ease of Online Booking:
# - Cleanliness

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

estimator = LogisticRegression()
selector = RFE(estimator, n_features_to_select=15)
selector = selector.fit(X_scaled, y)

# %%
selected_feature_indices = selector.get_support(indices=True)
X_scaled_selected_features = X_scaled[:, selected_feature_indices]

# %%
selected_feature_names = df.columns[selected_feature_indices]
print(selected_feature_names)
# Out:
# Index(['Gender', 'Age', 'Type of Travel', 'Flight Distance',
#        'Inflight wifi service', 'Departure/Arrival time convenient',
#        'Food and drink', 'Inflight entertainment', 'On-board service',
#        'Leg room service', 'Baggage handling', 'Checkin service',
#        'Inflight service', 'Cleanliness', 'Departure Delay in Minutes'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled_selected_features, y, test_size=0.25, random_state=42)
print(X_train.shape)
print(y_train.shape)
# Out:
# (77928, 15)
# (77928,)

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

svc = SVC(kernel="linear", C=1.)
svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     14677
#            1       0.88      0.83      0.86     11299
#
#     accuracy                           0.88     25976
#    macro avg       0.88      0.87      0.88     25976
# weighted avg       0.88      0.88      0.88     25976

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=100, solver='liblinear', penalty='l2', C=0.1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     14677
#            1       0.87      0.84      0.85     11299
#
#     accuracy                           0.88     25976
#    macro avg       0.88      0.87      0.87     25976
# weighted avg       0.88      0.88      0.88     25976

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89     14677
#            1       0.88      0.83      0.85     11299
#
#     accuracy                           0.87     25976
#    macro avg       0.87      0.87      0.87     25976
# weighted avg       0.87      0.87      0.87     25976

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.8))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.8))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train_cat, epochs=100, batch_size=1028, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/100
# 69/69 - 2s - loss: 0.5175 - accuracy: 0.7410 - val_loss: 0.3035 - val_accuracy: 0.8861 - 2s/epoch - 32ms/step
# Epoch 2/100
# 69/69 - 1s - loss: 0.2907 - accuracy: 0.8919 - val_loss: 0.1716 - val_accuracy: 0.9329 - 591ms/epoch - 9ms/step
# Epoch 3/100
# 69/69 - 1s - loss: 0.1946 - accuracy: 0.9269 - val_loss: 0.1387 - val_accuracy: 0.9450 - 570ms/epoch - 8ms/step
# Epoch 4/100
# 69/69 - 1s - loss: 0.1713 - accuracy: 0.9334 - val_loss: 0.1453 - val_accuracy: 0.9448 - 573ms/epoch - 8ms/step
# Epoch 5/100
# 69/69 - 1s - loss: 0.1494 - accuracy: 0.9409 - val_loss: 0.1302 - val_accuracy: 0.9467 - 572ms/epoch - 8ms/step
# Epoch 6/100
# 69/69 - 1s - loss: 0.1405 - accuracy: 0.9433 - val_loss: 0.1480 - val_accuracy: 0.9410 - 603ms/epoch - 9ms/step
# Epoch 7/100
# 69/69 - 1s - loss: 0.1348 - accuracy: 0.9456 - val_loss: 0.1155 - val_accuracy: 0.9547 - 581ms/epoch - 8ms/step
# Epoch 8/100
# 69/69 - 1s - loss: 0.1296 - accuracy: 0.9479 - val_loss: 0.1089 - val_accuracy: 0.9586 - 595ms/epoch - 9ms/step
# Epoch 9/100
# 69/69 - 1s - loss: 0.1243 - accuracy: 0.9511 - val_loss: 0.1110 - val_accuracy: 0.9555 - 589ms/epoch - 9ms/step
# Epoch 10/100
# 69/69 - 1s - loss: 0.1209 - accuracy: 0.9502 - val_loss: 0.1211 - val_accuracy: 0.9553 - 652ms/epoch - 9ms/step
# Epoch 11/100
# 69/69 - 1s - loss: 0.1152 - accuracy: 0.9525 - val_loss: 0.1026 - val_accuracy: 0.9591 - 655ms/epoch - 9ms/step
# Epoch 12/100
# 69/69 - 1s - loss: 0.1106 - accuracy: 0.9544 - val_loss: 0.1007 - val_accuracy: 0.9598 - 657ms/epoch - 10ms/step
# Epoch 13/100
# 69/69 - 1s - loss: 0.1095 - accuracy: 0.9541 - val_loss: 0.1031 - val_accuracy: 0.9580 - 577ms/epoch - 8ms/step
# Epoch 14/100
# 69/69 - 1s - loss: 0.1037 - accuracy: 0.9568 - val_loss: 0.0995 - val_accuracy: 0.9603 - 576ms/epoch - 8ms/step
# Epoch 15/100
# 69/69 - 1s - loss: 0.1087 - accuracy: 0.9537 - val_loss: 0.1015 - val_accuracy: 0.9603 - 568ms/epoch - 8ms/step
# Epoch 16/100
# 69/69 - 1s - loss: 0.1035 - accuracy: 0.9569 - val_loss: 0.1006 - val_accuracy: 0.9607 - 580ms/epoch - 8ms/step
# Epoch 17/100
# 69/69 - 1s - loss: 0.1053 - accuracy: 0.9549 - val_loss: 0.0992 - val_accuracy: 0.9623 - 677ms/epoch - 10ms/step
# Epoch 18/100
# 69/69 - 1s - loss: 0.1041 - accuracy: 0.9560 - val_loss: 0.0987 - val_accuracy: 0.9628 - 583ms/epoch - 8ms/step
# Epoch 19/100
# 69/69 - 1s - loss: 0.0981 - accuracy: 0.9582 - val_loss: 0.0952 - val_accuracy: 0.9636 - 609ms/epoch - 9ms/step
# Epoch 20/100
# 69/69 - 1s - loss: 0.0967 - accuracy: 0.9584 - val_loss: 0.0952 - val_accuracy: 0.9621 - 613ms/epoch - 9ms/step
# Epoch 21/100
# 69/69 - 1s - loss: 0.0964 - accuracy: 0.9582 - val_loss: 0.0952 - val_accuracy: 0.9620 - 735ms/epoch - 11ms/step
# Epoch 22/100
# 69/69 - 1s - loss: 0.0949 - accuracy: 0.9598 - val_loss: 0.0941 - val_accuracy: 0.9610 - 624ms/epoch - 9ms/step
# Epoch 23/100
# 69/69 - 1s - loss: 0.0951 - accuracy: 0.9587 - val_loss: 0.0950 - val_accuracy: 0.9612 - 656ms/epoch - 10ms/step
# Epoch 24/100
# 69/69 - 1s - loss: 0.0946 - accuracy: 0.9597 - val_loss: 0.0950 - val_accuracy: 0.9623 - 617ms/epoch - 9ms/step
# Epoch 25/100
# 69/69 - 1s - loss: 0.0938 - accuracy: 0.9593 - val_loss: 0.0889 - val_accuracy: 0.9660 - 590ms/epoch - 9ms/step
# Epoch 26/100
# 69/69 - 1s - loss: 0.0913 - accuracy: 0.9602 - val_loss: 0.1030 - val_accuracy: 0.9579 - 597ms/epoch - 9ms/step
# Epoch 27/100
# 69/69 - 1s - loss: 0.0902 - accuracy: 0.9610 - val_loss: 0.0965 - val_accuracy: 0.9630 - 593ms/epoch - 9ms/step
# Epoch 28/100
# 69/69 - 1s - loss: 0.0900 - accuracy: 0.9608 - val_loss: 0.0861 - val_accuracy: 0.9659 - 592ms/epoch - 9ms/step
# Epoch 29/100
# 69/69 - 1s - loss: 0.0884 - accuracy: 0.9617 - val_loss: 0.0933 - val_accuracy: 0.9627 - 599ms/epoch - 9ms/step
# Epoch 30/100
# 69/69 - 1s - loss: 0.0905 - accuracy: 0.9602 - val_loss: 0.0916 - val_accuracy: 0.9638 - 602ms/epoch - 9ms/step
# Epoch 31/100
# 69/69 - 1s - loss: 0.0895 - accuracy: 0.9614 - val_loss: 0.0904 - val_accuracy: 0.9624 - 583ms/epoch - 8ms/step
# Epoch 32/100
# 69/69 - 1s - loss: 0.0867 - accuracy: 0.9620 - val_loss: 0.0891 - val_accuracy: 0.9642 - 647ms/epoch - 9ms/step
# Epoch 33/100
# 69/69 - 1s - loss: 0.0840 - accuracy: 0.9625 - val_loss: 0.0866 - val_accuracy: 0.9654 - 583ms/epoch - 8ms/step
# Epoch 34/100
# 69/69 - 1s - loss: 0.0850 - accuracy: 0.9624 - val_loss: 0.0872 - val_accuracy: 0.9660 - 615ms/epoch - 9ms/step
# Epoch 35/100
# 69/69 - 1s - loss: 0.0850 - accuracy: 0.9629 - val_loss: 0.0900 - val_accuracy: 0.9629 - 620ms/epoch - 9ms/step
# Epoch 36/100
# 69/69 - 1s - loss: 0.0821 - accuracy: 0.9641 - val_loss: 0.0897 - val_accuracy: 0.9638 - 581ms/epoch - 8ms/step
# Epoch 37/100
# 69/69 - 1s - loss: 0.0839 - accuracy: 0.9634 - val_loss: 0.0879 - val_accuracy: 0.9645 - 589ms/epoch - 9ms/step
# Epoch 38/100
# 69/69 - 1s - loss: 0.0844 - accuracy: 0.9625 - val_loss: 0.0969 - val_accuracy: 0.9618 - 572ms/epoch - 8ms/step
# Epoch 39/100
# 69/69 - 1s - loss: 0.0842 - accuracy: 0.9635 - val_loss: 0.0857 - val_accuracy: 0.9665 - 604ms/epoch - 9ms/step
# Epoch 40/100
# 69/69 - 1s - loss: 0.0814 - accuracy: 0.9646 - val_loss: 0.0994 - val_accuracy: 0.9579 - 585ms/epoch - 8ms/step
# Epoch 41/100
# 69/69 - 1s - loss: 0.0827 - accuracy: 0.9635 - val_loss: 0.0857 - val_accuracy: 0.9656 - 600ms/epoch - 9ms/step
# Epoch 42/100
# 69/69 - 1s - loss: 0.0810 - accuracy: 0.9648 - val_loss: 0.0849 - val_accuracy: 0.9668 - 602ms/epoch - 9ms/step
# Epoch 43/100
# 69/69 - 1s - loss: 0.0799 - accuracy: 0.9653 - val_loss: 0.0842 - val_accuracy: 0.9652 - 626ms/epoch - 9ms/step
# Epoch 44/100
# 69/69 - 1s - loss: 0.0805 - accuracy: 0.9653 - val_loss: 0.0885 - val_accuracy: 0.9655 - 667ms/epoch - 10ms/step
# Epoch 45/100
# 69/69 - 1s - loss: 0.0799 - accuracy: 0.9653 - val_loss: 0.0850 - val_accuracy: 0.9666 - 694ms/epoch - 10ms/step
# Epoch 46/100
# 69/69 - 1s - loss: 0.0793 - accuracy: 0.9642 - val_loss: 0.0859 - val_accuracy: 0.9665 - 640ms/epoch - 9ms/step
# Epoch 47/100
# 69/69 - 1s - loss: 0.0788 - accuracy: 0.9646 - val_loss: 0.0886 - val_accuracy: 0.9648 - 728ms/epoch - 11ms/step
# Epoch 48/100
# 69/69 - 1s - loss: 0.0787 - accuracy: 0.9656 - val_loss: 0.0890 - val_accuracy: 0.9650 - 594ms/epoch - 9ms/step
# Epoch 49/100
# 69/69 - 1s - loss: 0.0780 - accuracy: 0.9662 - val_loss: 0.0869 - val_accuracy: 0.9668 - 575ms/epoch - 8ms/step
# Epoch 50/100
# 69/69 - 1s - loss: 0.0788 - accuracy: 0.9659 - val_loss: 0.0872 - val_accuracy: 0.9654 - 588ms/epoch - 9ms/step
# Epoch 51/100
# 69/69 - 1s - loss: 0.0741 - accuracy: 0.9669 - val_loss: 0.0855 - val_accuracy: 0.9650 - 650ms/epoch - 9ms/step
# Epoch 52/100
# 69/69 - 1s - loss: 0.0768 - accuracy: 0.9669 - val_loss: 0.0840 - val_accuracy: 0.9656 - 587ms/epoch - 9ms/step
# Epoch 53/100
# 69/69 - 1s - loss: 0.0765 - accuracy: 0.9665 - val_loss: 0.0926 - val_accuracy: 0.9628 - 572ms/epoch - 8ms/step
# Epoch 54/100
# 69/69 - 1s - loss: 0.0869 - accuracy: 0.9637 - val_loss: 0.1030 - val_accuracy: 0.9520 - 572ms/epoch - 8ms/step
# Epoch 55/100
# 69/69 - 1s - loss: 0.0769 - accuracy: 0.9665 - val_loss: 0.0856 - val_accuracy: 0.9645 - 606ms/epoch - 9ms/step
# Epoch 56/100
# 69/69 - 1s - loss: 0.0756 - accuracy: 0.9670 - val_loss: 0.0842 - val_accuracy: 0.9664 - 592ms/epoch - 9ms/step
# Epoch 57/100
# 69/69 - 1s - loss: 0.0737 - accuracy: 0.9666 - val_loss: 0.0864 - val_accuracy: 0.9654 - 591ms/epoch - 9ms/step
# Epoch 58/100
# 69/69 - 1s - loss: 0.0758 - accuracy: 0.9666 - val_loss: 0.0854 - val_accuracy: 0.9675 - 572ms/epoch - 8ms/step
# Epoch 59/100
# 69/69 - 1s - loss: 0.0770 - accuracy: 0.9666 - val_loss: 0.0915 - val_accuracy: 0.9625 - 578ms/epoch - 8ms/step
# Epoch 60/100
# 69/69 - 1s - loss: 0.0735 - accuracy: 0.9675 - val_loss: 0.0836 - val_accuracy: 0.9666 - 587ms/epoch - 9ms/step
# Epoch 61/100
# 69/69 - 1s - loss: 0.0717 - accuracy: 0.9676 - val_loss: 0.0896 - val_accuracy: 0.9656 - 591ms/epoch - 9ms/step
# Epoch 62/100
# 69/69 - 1s - loss: 0.0729 - accuracy: 0.9674 - val_loss: 0.0856 - val_accuracy: 0.9657 - 605ms/epoch - 9ms/step
# Epoch 63/100
# 69/69 - 1s - loss: 0.0733 - accuracy: 0.9676 - val_loss: 0.0861 - val_accuracy: 0.9651 - 574ms/epoch - 8ms/step
# Epoch 64/100
# 69/69 - 1s - loss: 0.0712 - accuracy: 0.9683 - val_loss: 0.0978 - val_accuracy: 0.9611 - 570ms/epoch - 8ms/step
# Epoch 65/100
# 69/69 - 1s - loss: 0.0719 - accuracy: 0.9683 - val_loss: 0.0843 - val_accuracy: 0.9674 - 583ms/epoch - 8ms/step
# Epoch 66/100
# 69/69 - 1s - loss: 0.0719 - accuracy: 0.9683 - val_loss: 0.0844 - val_accuracy: 0.9670 - 578ms/epoch - 8ms/step
# Epoch 67/100
# 69/69 - 1s - loss: 0.0690 - accuracy: 0.9691 - val_loss: 0.0954 - val_accuracy: 0.9618 - 577ms/epoch - 8ms/step
# Epoch 68/100
# 69/69 - 1s - loss: 0.0717 - accuracy: 0.9680 - val_loss: 0.0872 - val_accuracy: 0.9664 - 582ms/epoch - 8ms/step
# Epoch 69/100
# 69/69 - 1s - loss: 0.0706 - accuracy: 0.9688 - val_loss: 0.0879 - val_accuracy: 0.9642 - 571ms/epoch - 8ms/step
# Epoch 70/100
# 69/69 - 1s - loss: 0.0726 - accuracy: 0.9673 - val_loss: 0.0856 - val_accuracy: 0.9655 - 569ms/epoch - 8ms/step
# Epoch 71/100
# 69/69 - 1s - loss: 0.0704 - accuracy: 0.9686 - val_loss: 0.0943 - val_accuracy: 0.9628 - 568ms/epoch - 8ms/step
# Epoch 72/100
# 69/69 - 1s - loss: 0.0709 - accuracy: 0.9685 - val_loss: 0.0905 - val_accuracy: 0.9636 - 603ms/epoch - 9ms/step
# Epoch 73/100
# 69/69 - 1s - loss: 0.0701 - accuracy: 0.9683 - val_loss: 0.0843 - val_accuracy: 0.9661 - 576ms/epoch - 8ms/step
# Epoch 74/100
# 69/69 - 1s - loss: 0.0667 - accuracy: 0.9697 - val_loss: 0.0843 - val_accuracy: 0.9664 - 595ms/epoch - 9ms/step
# Epoch 75/100
# 69/69 - 1s - loss: 0.0670 - accuracy: 0.9694 - val_loss: 0.0862 - val_accuracy: 0.9652 - 628ms/epoch - 9ms/step
# Epoch 76/100
# 69/69 - 1s - loss: 0.0706 - accuracy: 0.9685 - val_loss: 0.0889 - val_accuracy: 0.9657 - 613ms/epoch - 9ms/step
# Epoch 77/100
# 69/69 - 1s - loss: 0.0696 - accuracy: 0.9692 - val_loss: 0.0887 - val_accuracy: 0.9647 - 617ms/epoch - 9ms/step
# Epoch 78/100
# 69/69 - 1s - loss: 0.0669 - accuracy: 0.9700 - val_loss: 0.0895 - val_accuracy: 0.9648 - 570ms/epoch - 8ms/step
# Epoch 79/100
# 69/69 - 1s - loss: 0.0689 - accuracy: 0.9687 - val_loss: 0.0859 - val_accuracy: 0.9657 - 577ms/epoch - 8ms/step
# Epoch 80/100
# 69/69 - 1s - loss: 0.0690 - accuracy: 0.9688 - val_loss: 0.0881 - val_accuracy: 0.9643 - 577ms/epoch - 8ms/step
# Epoch 81/100
# 69/69 - 1s - loss: 0.0674 - accuracy: 0.9696 - val_loss: 0.0851 - val_accuracy: 0.9677 - 573ms/epoch - 8ms/step
# Epoch 82/100
# 69/69 - 1s - loss: 0.0668 - accuracy: 0.9704 - val_loss: 0.0882 - val_accuracy: 0.9660 - 620ms/epoch - 9ms/step
# Epoch 83/100
# 69/69 - 1s - loss: 0.0659 - accuracy: 0.9703 - val_loss: 0.0876 - val_accuracy: 0.9648 - 569ms/epoch - 8ms/step
# Epoch 84/100
# 69/69 - 1s - loss: 0.0675 - accuracy: 0.9696 - val_loss: 0.0929 - val_accuracy: 0.9636 - 577ms/epoch - 8ms/step
# Epoch 85/100
# 69/69 - 1s - loss: 0.0684 - accuracy: 0.9688 - val_loss: 0.0856 - val_accuracy: 0.9652 - 571ms/epoch - 8ms/step
# Epoch 86/100
# 69/69 - 1s - loss: 0.0668 - accuracy: 0.9699 - val_loss: 0.0881 - val_accuracy: 0.9641 - 573ms/epoch - 8ms/step
# Epoch 87/100
# 69/69 - 1s - loss: 0.0700 - accuracy: 0.9692 - val_loss: 0.0927 - val_accuracy: 0.9600 - 582ms/epoch - 8ms/step
# Epoch 88/100
# 69/69 - 1s - loss: 0.0657 - accuracy: 0.9702 - val_loss: 0.0840 - val_accuracy: 0.9655 - 579ms/epoch - 8ms/step
# Epoch 89/100
# 69/69 - 1s - loss: 0.0644 - accuracy: 0.9705 - val_loss: 0.0848 - val_accuracy: 0.9651 - 606ms/epoch - 9ms/step
# Epoch 90/100
# 69/69 - 1s - loss: 0.0652 - accuracy: 0.9709 - val_loss: 0.0957 - val_accuracy: 0.9619 - 571ms/epoch - 8ms/step
# Epoch 91/100
# 69/69 - 1s - loss: 0.0660 - accuracy: 0.9702 - val_loss: 0.0851 - val_accuracy: 0.9659 - 595ms/epoch - 9ms/step
# Epoch 92/100
# 69/69 - 1s - loss: 0.0687 - accuracy: 0.9691 - val_loss: 0.0844 - val_accuracy: 0.9675 - 594ms/epoch - 9ms/step
# Epoch 93/100
# 69/69 - 1s - loss: 0.0637 - accuracy: 0.9707 - val_loss: 0.0960 - val_accuracy: 0.9624 - 573ms/epoch - 8ms/step
# Epoch 94/100
# 69/69 - 1s - loss: 0.0663 - accuracy: 0.9702 - val_loss: 0.0897 - val_accuracy: 0.9648 - 596ms/epoch - 9ms/step
# Epoch 95/100
# 69/69 - 1s - loss: 0.0624 - accuracy: 0.9716 - val_loss: 0.0890 - val_accuracy: 0.9660 - 575ms/epoch - 8ms/step
# Epoch 96/100
# 69/69 - 1s - loss: 0.0616 - accuracy: 0.9719 - val_loss: 0.0854 - val_accuracy: 0.9654 - 580ms/epoch - 8ms/step
# Epoch 97/100
# 69/69 - 1s - loss: 0.0618 - accuracy: 0.9722 - val_loss: 0.0870 - val_accuracy: 0.9641 - 580ms/epoch - 8ms/step
# Epoch 98/100
# 69/69 - 1s - loss: 0.0643 - accuracy: 0.9706 - val_loss: 0.0863 - val_accuracy: 0.9652 - 577ms/epoch - 8ms/step
# Epoch 99/100
# 69/69 - 1s - loss: 0.0636 - accuracy: 0.9710 - val_loss: 0.0859 - val_accuracy: 0.9637 - 577ms/epoch - 8ms/step
# Epoch 100/100
# 69/69 - 1s - loss: 0.0648 - accuracy: 0.9707 - val_loss: 0.0886 - val_accuracy: 0.9646 - 580ms/epoch - 8ms/step

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 812/812 [==============================] - 1s 1ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     14677
#            1       0.97      0.93      0.95     11299
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976
